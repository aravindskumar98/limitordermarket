# %% [markdown]
# <a href="https://colab.research.google.com/github/aravindskumar98/limitordermarket/blob/testing/dataPrep/FullRun_SnapShot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Feb  6 03:02:37 2022

@author: aravi
"""

import pandas as pd
import numpy as np
import pickle 

class env():
    
    def __init__(self,filepath,intervalSize):
        self.data_array = None
        self.load_data(filepath) ## Creates array of numpy array based on date
        self.orderbook_daily = []
        self.intervalSize = intervalSize * 60 ## in seconds
        for i,data in enumerate(self.data_array):
            print("Day : ",i+1)
            print('---------')
            self.orderbook_daily.append(Orderbook(data,self.intervalSize))

    def load_data(self,filepath):
        df = np.loadtxt(filepath,dtype = np.float32)
        # df = df[:10000,:]
        self.data_array = np.split(df, np.where(np.diff(df[:,1]))[0]+1)

## class for creating snapshots
class Orderbook:
    def __init__(self,data,intervalSize):
        # id,date,time,vd,vo,lp,isbuy
   
        ## Load data onto a numpy array
        self.data = data
        ## store the interval size/step size --> can be changed for finer control
        self.intervalSize = intervalSize
        self.tstart = self.data[0][2]
        self.tend = self.data[-1][2]
        # print(self.tstart,self.tend)
        
        self.snaps = []
        self.generate_snaps()        
    
    def generate_snaps(self):
        start = self.tstart
        count = 1
        while start+self.intervalSize < self.tend:
            print("Interval Number : ",count)
            snap = snapshot(self.data,start,self.intervalSize)
            snap.describe()
            print("..")
            self.snaps.append(snap)
            start+=self.intervalSize  
            count+=1

class snapshot:
    
    def __init__(self,orderbook,startTime,intervalSize):
        self.data = orderbook
        self.startTime = startTime
        self.intervalSize = intervalSize
        ## initialising the descriptors of the state
        self.sell, self.buy= [],[]
        self.trade_list = []
        self.sellSize,self.buySize,self.tradeSize = 0,0,0
        self.BASpread, self.volatility = 0,{"buy":0,"sell":0,"trade":0}
        
        self.generateSnap()

        
    ## This function resets the state and sets it back to the initial empty condition
    def resetState(self):
        self.sell, self.buy = [],[]
        self.trade_list = []
        self.sellSize, self.buySize, self.tradeSize = 0,0,0
        print("..")
    
    def sortHeap(self):
        ## heap will be implemented in later updates
        if self.buy:    
            self.buy.sort()
        if self.sell:
            self.sell.sort(reverse=True)
        
    def trade_act(self): ## this function executes trades in the current limit order snapshot
        if not self.buy or not self.sell:
            return
        
        while self.sell and self.buy and self.sell[-1][0] <= self.buy[-1][0]:
            # print(self.trade_list)
            tradeVal = min(self.buy[-1][1],self.sell[-1][1])
            self.trade_list.append((self.buy[-1][0],self.sell[-1][0],tradeVal))
            self.buy[-1][1]-=tradeVal
            self.sell[-1][1]-=tradeVal
            if self.buy[-1][1]==0:
                self.buy.pop()
            if self.sell[-1][1]==0:
                self.sell.pop()
            self.tradeSize+=1
            
    def generateSnap(self):
        ## reset leftovers from the last state
        self.resetState()
        
        ## Iterate through all transactions within the intervalSize
        for row in self.data:
            # print(row)
            if row[2] < self.startTime+self.intervalSize:
                if row[5]==0:
                    continue ### Assuming that garbage values can be removed
                elif row[-1]==1:
                    self.buy.append([row[5],row[4]])
                    self.buySize+=1
                else:
                    self.sell.append([row[5],row[4]])
                    self.sellSize+=1
                
                ## sort the buy side and sell side postings and generate current snapshot
                self.sortHeap()
                self.trade_act()
                        
        
        self.calculate_state()
    
    def find_volatility(self):
        trade = np.array(self.trade_list)
        buy = np.array(self.buy)
        sell = np.array(self.sell)
        self.volatility["trade"] = np.std(trade[:,0])
        self.volatility["buy"] = np.std(buy[:,0])
        self.volatility["sell"] = np.std(sell[:,0])
        
    
    def calculate_state(self):
        if self.buy and self.sell:
            self.BASpread = self.sell[-1][0]-self.buy[-1][0]
        self.find_volatility()

    ##function to display stuff
    def describe(self):
        print("SELL SIDE")
        size = min(len(self.sell),6)
        for i in range(1,min(len(self.sell),6)):
            print(self.sell[-size+i])
        
        print("<---------->")
        for i in range(1,min(len(self.buy),6)):
            print(self.buy[-i])
        print("BUY SIDE")
            
        for key in self.volatility:
            print(f"Volatility : {key} = {self.volatility[key]}")
        
        print(f"Current bid ask spread = {self.BASpread}")
            

Env = env("/content/drive/MyDrive/limitorderbook/numpydatabook_full_2.txt",30)
# Out:
# Streaming output truncated to the last 5000 lines.
# SELL SIDE
# [2210.0, 5.0]
# [2210.0, 5.0]
# [2210.0, 5.0]
# [2210.0, 5.0]
# [2210.0, 2.0]
# <---------->
# [2197.0, 1036.0]
# [2193.1, 108.0]
# [2193.0, 253.0]
# [2193.0, 200.0]
# [2193.0, 200.0]
# BUY SIDE
# Volatility : buy = 88.70521545410156
# Volatility : sell = 86.54524230957031
# Volatility : trade = 28.741233825683594
# Current bid ask spread = 13.0
# ..
# Interval Number :  2
# ..
# SELL SIDE
# [2229.75, 15.0]
# [2229.0, 10.0]
# [2228.9, 10.0]
# [2228.85, 15.0]
# [2228.0, 2.0]
# <---------->
# [2226.1, 62.0]
# [2226.1, 47.0]
# [2226.0, 50.0]
# [2226.0, 1.0]
# [2225.8, 24.0]
# BUY SIDE
# Volatility : buy = 89.95796203613281
# Volatility : sell = 75.1060791015625
# Volatility : trade = 27.680173873901367
# Current bid ask spread = 1.89990234375
# ..
# Interval Number :  3
# ..
# SELL SIDE
# [2214.7, 5.0]
# [2214.5, 1.0]
# [2212.25, 25.0]
# [2212.25, 10.0]
# [2211.5, 73.0]
# <---------->
# [2211.1, 18.0]
# [2210.55, 15.0]
# [2210.55, 15.0]
# [2210.5, 7.0]
# [2210.5, 4.0]
# BUY SIDE
# Volatility : buy = 84.35692596435547
# Volatility : sell = 74.34957885742188
# Volatility : trade = 25.259111404418945
# Current bid ask spread = 0.39990234375
# ..
# Interval Number :  4
# ..
# SELL SIDE
# [2214.8, 193.0]
# [2214.8, 185.0]
# [2214.8, 185.0]
# [2214.8, 39.0]
# [2214.75, 5.0]
# <---------->
# [2211.1, 200.0]
# [2211.05, 20.0]
# [2211.05, 10.0]
# [2211.0, 100.0]
# [2211.0, 10.0]
# BUY SIDE
# Volatility : buy = 72.54087829589844
# Volatility : sell = 71.9585189819336
# Volatility : trade = 24.491477966308594
# Current bid ask spread = 3.64990234375
# ..
# Interval Number :  5
# ..
# SELL SIDE
# [2234.5, 5.0]
# [2234.4, 150.0]
# [2234.4, 20.0]
# [2234.0, 190.0]
# [2233.0, 3.0]
# <---------->
# [2230.1, 192.0]
# [2230.1, 190.0]
# [2230.0, 200.0]
# [2230.0, 1.0]
# [2226.25, 393.0]
# BUY SIDE
# Volatility : buy = 72.23770904541016
# Volatility : sell = 71.76366424560547
# Volatility : trade = 24.92357063293457
# Current bid ask spread = 2.89990234375
# ..
# Interval Number :  6
# ..
# SELL SIDE
# [2240.0, 250.0]
# [2240.0, 200.0]
# [2240.0, 200.0]
# [2240.0, 200.0]
# [2240.0, 123.0]
# <---------->
# [2238.05, 4.0]
# [2238.0, 63.0]
# [2238.0, 10.0]
# [2238.0, 10.0]
# [2237.4, 50.0]
# BUY SIDE
# Volatility : buy = 71.79736328125
# Volatility : sell = 70.66812896728516
# Volatility : trade = 28.017959594726562
# Current bid ask spread = 1.949951171875
# ..
# Interval Number :  7
# ..
# SELL SIDE
# [2254.95, 12.0]
# [2254.95, 12.0]
# [2254.95, 5.0]
# [2254.95, 4.0]
# [2254.9, 20.0]
# <---------->
# [2248.2, 5.0]
# [2244.05, 24.0]
# [2244.05, 2.0]
# [2244.0, 200.0]
# [2242.0, 100.0]
# BUY SIDE
# Volatility : buy = 73.5953140258789
# Volatility : sell = 66.77083587646484
# Volatility : trade = 30.26296043395996
# Current bid ask spread = 6.699951171875
# ..
# Interval Number :  8
# ..
# SELL SIDE
# [2304.95, 10.0]
# [2304.95, 10.0]
# [2303.0, 33.0]
# [2302.95, 50.0]
# [2302.9, 8.0]
# <---------->
# [2300.15, 95.0]
# [2300.15, 78.0]
# [2300.15, 76.0]
# [2300.15, 76.0]
# [2300.15, 50.0]
# BUY SIDE
# Volatility : buy = 78.01666259765625
# Volatility : sell = 67.88239288330078
# Volatility : trade = 44.90822219848633
# Current bid ask spread = 2.75
# ..
# Interval Number :  9
# ..
# SELL SIDE
# [2304.5, 3.0]
# [2304.0, 24.0]
# [2303.0, 2.0]
# [2300.0, 30.0]
# [2300.0, 20.0]
# <---------->
# [2295.0, 41.0]
# [2295.0, 35.0]
# [2295.0, 35.0]
# [2295.0, 25.0]
# [2295.0, 13.0]
# BUY SIDE
# Volatility : buy = 80.87483978271484
# Volatility : sell = 63.65462112426758
# Volatility : trade = 45.711238861083984
# Current bid ask spread = 5.0
# ..
# Interval Number :  10
# ..
# SELL SIDE
# [2294.65, 7.0]
# [2294.65, 3.0]
# [2292.0, 5.0]
# [2291.95, 15.0]
# [2291.8, 10.0]
# <---------->
# [2291.0, 10.0]
# [2290.05, 9.0]
# [2290.0, 10.0]
# [2290.0, 10.0]
# [2290.0, 5.0]
# BUY SIDE
# Volatility : buy = 78.82170867919922
# Volatility : sell = 61.23491668701172
# Volatility : trade = 45.564361572265625
# Current bid ask spread = 0.800048828125
# ..
# Interval Number :  11
# ..
# SELL SIDE
# [2334.9, 10.0]
# [2334.9, 10.0]
# [2334.9, 10.0]
# [2334.8, 5.0]
# [2334.75, 15.0]
# <---------->
# [2333.3, 50.0]
# [2332.0, 49.0]
# [2330.1, 50.0]
# [2330.05, 267.0]
# [2330.05, 209.0]
# BUY SIDE
# Volatility : buy = 81.64419555664062
# Volatility : sell = 62.6031379699707
# Volatility : trade = 49.37632369995117
# Current bid ask spread = 1.449951171875
# ..
# Interval Number :  12
# ..
# SELL SIDE
# [2340.0, 217.0]
# [2340.0, 200.0]
# [2340.0, 200.0]
# [2340.0, 200.0]
# [2340.0, 100.0]
# <---------->
# [2339.1, 2.0]
# [2338.1, 3.0]
# [2338.0, 5.0]
# [2338.0, 1.0]
# [2333.3, 47.0]
# BUY SIDE
# Volatility : buy = 82.69878387451172
# Volatility : sell = 64.94300842285156
# Volatility : trade = 50.86174011230469
# Current bid ask spread = 0.89990234375
# ..
# Day :  43
# ---------
# Interval Number :  1
# ..
# SELL SIDE
# [2299.75, 10.0]
# [2299.65, 10.0]
# [2295.0, 1.0]
# [2295.0, 1.0]
# [2295.0, 1.0]
# <---------->
# [2291.1, 35.0]
# [2291.1, 33.0]
# [2291.1, 5.0]
# [2291.1, 2.0]
# [2291.0, 100.0]
# BUY SIDE
# Volatility : buy = 73.25466918945312
# Volatility : sell = 76.63353729248047
# Volatility : trade = 30.670011520385742
# Current bid ask spread = 3.89990234375
# ..
# Interval Number :  2
# ..
# SELL SIDE
# [2289.95, 400.0]
# [2289.95, 400.0]
# [2289.95, 265.0]
# [2289.8, 22.0]
# [2289.8, 6.0]
# <---------->
# [2287.1, 30.0]
# [2287.05, 200.0]
# [2287.05, 30.0]
# [2287.05, 5.0]
# [2287.05, 4.0]
# BUY SIDE
# Volatility : buy = 63.805442810058594
# Volatility : sell = 79.70331573486328
# Volatility : trade = 36.547183990478516
# Current bid ask spread = 2.699951171875
# ..
# Interval Number :  3
# ..
# SELL SIDE
# [2297.0, 5.0]
# [2297.0, 5.0]
# [2297.0, 5.0]
# [2297.0, 5.0]
# [2297.0, 5.0]
# <---------->
# [2293.05, 163.0]
# [2293.05, 30.0]
# [2293.0, 25.0]
# [2293.0, 25.0]
# [2293.0, 21.0]
# BUY SIDE
# Volatility : buy = 61.58407974243164
# Volatility : sell = 75.97632598876953
# Volatility : trade = 33.2954216003418
# Current bid ask spread = 3.949951171875
# ..
# Interval Number :  4
# ..
# SELL SIDE
# [2293.5, 20.0]
# [2293.5, 1.0]
# [2293.45, 54.0]
# [2293.0, 100.0]
# [2293.0, 10.0]
# <---------->
# [2291.0, 2.0]
# [2291.0, 1.0]
# [2290.85, 2.0]
# [2290.15, 150.0]
# [2290.15, 10.0]
# BUY SIDE
# Volatility : buy = 60.67124557495117
# Volatility : sell = 72.36613464355469
# Volatility : trade = 35.07868957519531
# Current bid ask spread = 2.0
# ..
# Interval Number :  5
# ..
# SELL SIDE
# [2306.2, 5.0]
# [2306.2, 5.0]
# [2306.2, 1.0]
# [2306.0, 50.0]
# [2306.0, 7.0]
# <---------->
# [2301.2, 49.0]
# [2300.0, 10.0]
# [2300.0, 7.0]
# [2300.0, 1.0]
# [2298.0, 10.0]
# BUY SIDE
# Volatility : buy = 61.929378509521484
# Volatility : sell = 71.6543960571289
# Volatility : trade = 31.172706604003906
# Current bid ask spread = 4.800048828125
# ..
# Interval Number :  6
# ..
# SELL SIDE
# [2331.9, 58.0]
# [2331.9, 9.0]
# [2331.0, 5.0]
# [2330.0, 200.0]
# [2330.0, 138.0]
# <---------->
# [2327.55, 162.0]
# [2327.5, 74.0]
# [2327.5, 46.0]
# [2327.5, 3.0]
# [2327.45, 185.0]
# BUY SIDE
# Volatility : buy = 61.77219772338867
# Volatility : sell = 68.5567398071289
# Volatility : trade = 29.176851272583008
# Current bid ask spread = 2.449951171875
# ..
# Interval Number :  7
# ..
# SELL SIDE
# [2314.65, 15.0]
# [2313.9, 7.0]
# [2310.0, 5.0]
# [2309.9, 10.0]
# [2309.0, 23.0]
# <---------->
# [2305.0, 272.0]
# [2305.0, 168.0]
# [2305.0, 25.0]
# [2305.0, 10.0]
# [2305.0, 5.0]
# BUY SIDE
# Volatility : buy = 59.9822998046875
# Volatility : sell = 65.4712905883789
# Volatility : trade = 28.212112426757812
# Current bid ask spread = 4.0
# ..
# Interval Number :  8
# ..
# SELL SIDE
# [2294.6, 10.0]
# [2294.0, 25.0]
# [2294.0, 2.0]
# [2294.0, 2.0]
# [2291.05, 195.0]
# <---------->
# [2290.1, 13.0]
# [2290.1, 10.0]
# [2290.1, 10.0]
# [2290.1, 10.0]
# [2290.1, 5.0]
# BUY SIDE
# Volatility : buy = 59.784908294677734
# Volatility : sell = 64.69063568115234
# Volatility : trade = 27.949249267578125
# Current bid ask spread = 0.949951171875
# ..
# Interval Number :  9
# ..
# SELL SIDE
# [2289.95, 15.0]
# [2289.95, 15.0]
# [2289.95, 15.0]
# [2289.95, 15.0]
# [2286.95, 41.0]
# <---------->
# [2286.0, 236.0]
# [2286.0, 206.0]
# [2286.0, 199.0]
# [2286.0, 190.0]
# [2286.0, 100.0]
# BUY SIDE
# Volatility : buy = 58.007076263427734
# Volatility : sell = 63.84053421020508
# Volatility : trade = 28.85550308227539
# Current bid ask spread = 0.949951171875
# ..
# Interval Number :  10
# ..
# SELL SIDE
# [2288.7, 20.0]
# [2288.0, 2.0]
# [2286.95, 50.0]
# [2286.95, 25.0]
# [2286.0, 1.0]
# <---------->
# [2285.0, 2.0]
# [2285.0, 5.0]
# [2285.0, 5.0]
# [2285.0, 5.0]
# [2285.0, 5.0]
# BUY SIDE
# Volatility : buy = 54.52541732788086
# Volatility : sell = 65.4126205444336
# Volatility : trade = 28.670852661132812
# Current bid ask spread = 1.0
# ..
# Interval Number :  11
# ..
# SELL SIDE
# [2288.0, 2.0]
# [2287.0, 21.0]
# [2286.95, 50.0]
# [2286.95, 8.0]
# [2285.0, 1.0]
# <---------->
# [2280.05, 36.0]
# [2280.05, 70.0]
# [2280.05, 69.0]
# [2280.05, 68.0]
# [2280.05, 68.0]
# BUY SIDE
# Volatility : buy = 53.157527923583984
# Volatility : sell = 66.15449523925781
# Volatility : trade = 28.457876205444336
# Current bid ask spread = 4.949951171875
# ..
# Day :  44
# ---------
# Interval Number :  1
# ..
# SELL SIDE
# [2187.0, 5.0]
# [2187.0, 1.0]
# [2186.95, 5.0]
# [2186.9, 200.0]
# [2186.9, 180.0]
# <---------->
# [2180.0, 10.0]
# [2176.0, 10.0]
# [2171.0, 50.0]
# [2171.0, 10.0]
# [2170.1, 200.0]
# BUY SIDE
# Volatility : buy = 76.66397094726562
# Volatility : sell = 75.92768859863281
# Volatility : trade = 16.398134231567383
# Current bid ask spread = 6.89990234375
# ..
# Interval Number :  2
# ..
# SELL SIDE
# [2215.05, 10.0]
# [2215.0, 600.0]
# [2215.0, 200.0]
# [2215.0, 200.0]
# [2215.0, 67.0]
# <---------->
# [2211.0, 5.0]
# [2210.0, 37.0]
# [2210.0, 10.0]
# [2210.0, 10.0]
# [2210.0, 1.0]
# BUY SIDE
# Volatility : buy = 74.97502899169922
# Volatility : sell = 57.00959014892578
# Volatility : trade = 24.79340362548828
# Current bid ask spread = 4.0
# ..
# Interval Number :  3
# ..
# SELL SIDE
# [2209.95, 200.0]
# [2209.95, 30.0]
# [2209.95, 10.0]
# [2209.9, 100.0]
# [2209.85, 85.0]
# <---------->
# [2206.05, 120.0]
# [2206.05, 5.0]
# [2205.0, 245.0]
# [2205.0, 20.0]
# [2205.0, 14.0]
# BUY SIDE
# Volatility : buy = 75.07920837402344
# Volatility : sell = 53.99628448486328
# Volatility : trade = 24.13914680480957
# Current bid ask spread = 3.800048828125
# ..
# Interval Number :  4
# ..
# SELL SIDE
# [2215.0, 1.0]
# [2214.95, 200.0]
# [2214.95, 200.0]
# [2214.95, 97.0]
# [2211.2, 1.0]
# <---------->
# [2211.15, 183.0]
# [2211.1, 52.0]
# [2211.1, 32.0]
# [2211.1, 10.0]
# [2211.1, 10.0]
# BUY SIDE
# Volatility : buy = 74.87189483642578
# Volatility : sell = 52.267452239990234
# Volatility : trade = 23.155872344970703
# Current bid ask spread = 0.050048828125
# ..
# Interval Number :  5
# ..
# SELL SIDE
# [2212.0, 5.0]
# [2212.0, 3.0]
# [2211.95, 10.0]
# [2211.9, 200.0]
# [2211.9, 161.0]
# <---------->
# [2210.05, 189.0]
# [2210.05, 189.0]
# [2210.05, 112.0]
# [2210.05, 31.0]
# [2210.05, 20.0]
# BUY SIDE
# Volatility : buy = 73.09580993652344
# Volatility : sell = 51.136863708496094
# Volatility : trade = 22.47052764892578
# Current bid ask spread = 1.849853515625
# ..
# Interval Number :  6
# ..
# SELL SIDE
# [2212.0, 200.0]
# [2212.0, 200.0]
# [2212.0, 5.0]
# [2212.0, 2.0]
# [2211.8, 5.0]
# <---------->
# [2210.0, 553.0]
# [2210.0, 1.0]
# [2210.0, 1.0]
# [2210.0, 1.0]
# [2210.0, 1.0]
# BUY SIDE
# Volatility : buy = 74.0700912475586
# Volatility : sell = 51.1119384765625
# Volatility : trade = 21.64927864074707
# Current bid ask spread = 1.800048828125
# ..
# Interval Number :  7
# ..
# SELL SIDE
# [2218.5, 5.0]
# [2218.5, 2.0]
# [2218.15, 2.0]
# [2218.0, 500.0]
# [2218.0, 102.0]
# <---------->
# [2216.25, 55.0]
# [2216.2, 112.0]
# [2216.2, 23.0]
# [2216.2, 15.0]
# [2216.15, 200.0]
# BUY SIDE
# Volatility : buy = 72.05389404296875
# Volatility : sell = 52.86079025268555
# Volatility : trade = 22.82513427734375
# Current bid ask spread = 1.75
# ..
# Interval Number :  8
# ..
# SELL SIDE
# [2230.1, 10.0]
# [2230.1, 10.0]
# [2230.1, 5.0]
# [2230.05, 10.0]
# [2230.0, 4460.0]
# <---------->
# [2226.0, 4958.0]
# [2224.0, 47.0]
# [2221.1, 5.0]
# [2221.1, 2.0]
# [2220.0, 25.0]
# BUY SIDE
# Volatility : buy = 71.13081359863281
# Volatility : sell = 56.32039260864258
# Volatility : trade = 28.663959503173828
# Current bid ask spread = 4.0
# ..
# Interval Number :  9
# ..
# SELL SIDE
# [2289.95, 15.0]
# [2289.95, 15.0]
# [2289.95, 3.0]
# [2289.75, 54.0]
# [2277.9, 5.0]
# <---------->
# [2270.15, 41.0]
# [2270.05, 30.0]
# [2270.0, 23.0]
# [2270.0, 20.0]
# [2270.0, 20.0]
# BUY SIDE
# Volatility : buy = 72.66545104980469
# Volatility : sell = 48.54570388793945
# Volatility : trade = 41.11568832397461
# Current bid ask spread = 7.75
# ..
# Interval Number :  10
# ..
# SELL SIDE
# [2267.0, 43.0]
# [2265.0, 50.0]
# [2265.0, 25.0]
# [2265.0, 10.0]
# [2263.0, 41.0]
# <---------->
# [2260.0, 200.0]
# [2260.0, 200.0]
# [2260.0, 150.0]
# [2260.0, 100.0]
# [2260.0, 75.0]
# BUY SIDE
# Volatility : buy = 71.67507934570312
# Volatility : sell = 46.799476623535156
# Volatility : trade = 40.9209098815918
# Current bid ask spread = 3.0
# ..
# Interval Number :  11
# ..
# SELL SIDE
# [2230.0, 53.0]
# [2230.0, 10.0]
# [2229.85, 50.0]
# [2229.0, 200.0]
# [2228.0, 222.0]
# <---------->
# [2227.1, 169.0]
# [2227.1, 20.0]
# [2227.05, 18.0]
# [2227.05, 6.0]
# [2227.0, 220.0]
# BUY SIDE
# Volatility : buy = 69.80358123779297
# Volatility : sell = 50.17607498168945
# Volatility : trade = 39.333988189697266
# Current bid ask spread = 0.89990234375
# ..
# Day :  45
# ---------
# Interval Number :  1
# ..
# SELL SIDE
# [2235.0, 1.0]
# [2235.0, 1.0]
# [2235.0, 1.0]
# [2233.0, 77.0]
# [2232.0, 1.0]
# <---------->
# [2230.65, 84.0]
# [2230.5, 200.0]
# [2230.45, 200.0]
# [2230.3, 200.0]
# [2230.3, 113.0]
# BUY SIDE
# Volatility : buy = 69.0535659790039
# Volatility : sell = 64.666015625
# Volatility : trade = 18.995317459106445
# Current bid ask spread = 1.35009765625
# ..
# Interval Number :  2
# ..
# SELL SIDE
# [2245.0, 1.0]
# [2244.85, 200.0]
# [2244.85, 82.0]
# [2239.95, 20.0]
# [2239.0, 10.0]
# <---------->
# [2235.05, 74.0]
# [2235.05, 20.0]
# [2235.0, 200.0]
# [2235.0, 200.0]
# [2235.0, 100.0]
# BUY SIDE
# Volatility : buy = 62.34516143798828
# Volatility : sell = 59.92021942138672
# Volatility : trade = 21.98762321472168
# Current bid ask spread = 3.949951171875
# ..
# Interval Number :  3
# ..
# SELL SIDE
# [2235.0, 50.0]
# [2235.0, 10.0]
# [2232.0, 90.0]
# [2231.0, 5.0]
# [2231.0, 1.0]
# <---------->
# [2230.0, 5.0]
# [2230.0, 4.0]
# [2230.0, 4.0]
# [2230.0, 4.0]
# [2230.0, 4.0]
# BUY SIDE
# Volatility : buy = 56.6334342956543
# Volatility : sell = 59.22849655151367
# Volatility : trade = 20.139333724975586
# Current bid ask spread = 1.0
# ..
# Interval Number :  4
# ..
# SELL SIDE
# [2230.0, 1.0]
# [2229.0, 1.0]
# [2226.0, 3.0]
# [2225.0, 5.0]
# [2224.0, 10.0]
# <---------->
# [2220.15, 165.0]
# [2220.15, 164.0]
# [2220.15, 163.0]
# [2220.15, 158.0]
# [2220.15, 153.0]
# BUY SIDE
# Volatility : buy = 54.58451461791992
# Volatility : sell = 61.01393127441406
# Volatility : trade = 20.988262176513672
# Current bid ask spread = 3.85009765625
# ..
# Interval Number :  5
# ..
# SELL SIDE
# [2223.95, 20.0]
# [2220.2, 12.0]
# [2220.0, 1.0]
# [2218.0, 50.0]
# [2217.0, 40.0]
# <---------->
# [2212.0, 38.0]
# [2212.0, 51.0]
# [2212.0, 27.0]
# [2212.0, 10.0]
# [2212.0, 10.0]
# BUY SIDE
# Volatility : buy = 53.75465393066406
# Volatility : sell = 59.90007400512695
# Volatility : trade = 20.219852447509766
# Current bid ask spread = 5.0
# ..
# Interval Number :  6
# ..
# SELL SIDE
# [2215.0, 5.0]
# [2215.0, 1.0]
# [2214.95, 10.0]
# [2214.9, 9.0]
# [2214.7, 5.0]
# <---------->
# [2213.15, 114.0]
# [2213.15, 68.0]
# [2212.75, 10.0]
# [2212.75, 10.0]
# [2212.6, 399.0]
# BUY SIDE
# Volatility : buy = 53.147216796875
# Volatility : sell = 59.97746658325195
# Volatility : trade = 20.0134220123291
# Current bid ask spread = 1.550048828125
# ..
# Interval Number :  7
# ..
# SELL SIDE
# [2224.75, 103.0]
# [2224.75, 103.0]
# [2224.7, 20.0]
# [2224.65, 106.0]
# [2224.4, 167.0]
# <---------->
# [2220.45, 70.0]
# [2220.35, 100.0]
# [2220.35, 28.0]
# [2220.35, 15.0]
# [2220.35, 13.0]
# BUY SIDE
# Volatility : buy = 54.261131286621094
# Volatility : sell = 58.8841438293457
# Volatility : trade = 20.62009048461914
# Current bid ask spread = 3.949951171875
# ..
# Interval Number :  8
# ..
# SELL SIDE
# [2224.65, 106.0]
# [2224.4, 67.0]
# [2223.85, 20.0]
# [2223.65, 10.0]
# [2221.9, 1788.0]
# <---------->
# [2215.0, 198.0]
# [2215.0, 157.0]
# [2215.0, 100.0]
# [2215.0, 50.0]
# [2215.0, 50.0]
# BUY SIDE
# Volatility : buy = 57.92186737060547
# Volatility : sell = 58.42889404296875
# Volatility : trade = 20.433063507080078
# Current bid ask spread = 6.89990234375
# ..
# Interval Number :  9
# ..
# SELL SIDE
# [2214.65, 30.0]
# [2214.65, 30.0]
# [2214.0, 300.0]
# [2214.0, 2.0]
# [2210.0, 5.0]
# <---------->
# [2205.4, 49.0]
# [2205.4, 70.0]
# [2205.4, 30.0]
# [2205.4, 20.0]
# [2205.4, 10.0]
# BUY SIDE
# Volatility : buy = 55.864044189453125
# Volatility : sell = 56.639862060546875
# Volatility : trade = 23.65472984313965
# Current bid ask spread = 4.60009765625
# ..
# Interval Number :  10
# ..
# SELL SIDE
# [2207.5, 9.0]
# [2207.0, 5.0]
# [2207.0, 5.0]
# [2207.0, 5.0]
# [2206.9, 10.0]
# <---------->
# [2205.0, 112.0]
# [2205.0, 111.0]
# [2205.0, 111.0]
# [2205.0, 110.0]
# [2205.0, 108.0]
# BUY SIDE
# Volatility : buy = 54.27924346923828
# Volatility : sell = 54.7384147644043
# Volatility : trade = 26.131895065307617
# Current bid ask spread = 1.89990234375
# ..
# Interval Number :  11
# ..
# SELL SIDE
# [2209.0, 1.0]
# [2209.0, 1.0]
# [2208.0, 25.0]
# [2208.0, 5.0]
# [2207.95, 5.0]
# <---------->
# [2206.15, 113.0]
# [2206.15, 2.0]
# [2206.15, 2.0]
# [2206.0, 100.0]
# [2206.0, 50.0]
# BUY SIDE
# Volatility : buy = 53.390708923339844
# Volatility : sell = 52.564395904541016
# Volatility : trade = 25.470582962036133
# Current bid ask spread = 1.800048828125
# ..
# Day :  46
# ---------
# Interval Number :  1
# ..
# SELL SIDE
# [2085.0, 2.0]
# [2085.0, 1.0]
# [2084.9, 50.0]
# [2084.9, 5.0]
# [2084.0, 11.0]
# <---------->
# [2080.15, 60.0]
# [2080.1, 100.0]
# [2080.1, 56.0]
# [2080.1, 5.0]
# [2080.05, 200.0]
# BUY SIDE
# Volatility : buy = 53.2972526550293
# Volatility : sell = 92.38811492919922
# Volatility : trade = 33.66800308227539
# Current bid ask spread = 3.85009765625
# ..
# Interval Number :  2
# ..
# SELL SIDE
# [1998.9, 100.0]
# [1998.9, 83.0]
# [1995.0, 1.0]
# [1995.0, 1.0]
# [1990.0, 1.0]
# <---------->
# [1987.0, 159.0]
# [1987.0, 73.0]
# [1987.0, 10.0]
# [1986.1, 400.0]
# [1986.1, 400.0]
# BUY SIDE
# Volatility : buy = 41.62176513671875
# Volatility : sell = 96.26676940917969
# Volatility : trade = 47.00177001953125
# Current bid ask spread = 3.0
# ..
# Interval Number :  3
# ..
# SELL SIDE
# [1999.0, 190.0]
# [1999.0, 50.0]
# [1999.0, 25.0]
# [1999.0, 10.0]
# [1998.0, 42.0]
# <---------->
# [1995.0, 1.0]
# [1990.05, 30.0]
# [1990.0, 8745.0]
# [1990.0, 376.0]
# [1990.0, 100.0]
# BUY SIDE
# Volatility : buy = 39.203128814697266
# Volatility : sell = 101.07626342773438
# Volatility : trade = 54.865543365478516
# Current bid ask spread = 3.0
# ..
# Interval Number :  4
# ..
# SELL SIDE
# [2049.9, 200.0]
# [2049.9, 200.0]
# [2049.9, 100.0]
# [2049.9, 100.0]
# [2049.9, 10.0]
# <---------->
# [2045.0, 77.0]
# [2045.0, 21.0]
# [2042.5, 10.0]
# [2042.25, 10.0]
# [2042.0, 239.0]
# BUY SIDE
# Volatility : buy = 51.54441452026367
# Volatility : sell = 88.8382339477539
# Volatility : trade = 49.2025032043457
# Current bid ask spread = 4.89990234375
# ..
# Interval Number :  5
# ..
# SELL SIDE
# [2043.85, 1.0]
# [2042.0, 61.0]
# [2041.05, 50.0]
# [2041.05, 2.0]
# [2040.15, 198.0]
# <---------->
# [2038.55, 146.0]
# [2038.5, 5.0]
# [2038.05, 38.0]
# [2038.05, 1.0]
# [2038.0, 150.0]
# BUY SIDE
# Volatility : buy = 52.20994186401367
# Volatility : sell = 84.2188491821289
# Volatility : trade = 49.392791748046875
# Current bid ask spread = 1.5999755859375
# ..
# Interval Number :  6
# ..
# SELL SIDE
# [2049.6, 10.0]
# [2049.5, 200.0]
# [2049.5, 50.0]
# [2049.5, 50.0]
# [2049.5, 4.0]
# <---------->
# [2045.0, 10.0]
# [2045.0, 10.0]
# [2044.05, 5.0]
# [2044.0, 15.0]
# [2043.05, 5.0]
# BUY SIDE
# Volatility : buy = 56.17632293701172
# Volatility : sell = 79.26350402832031
# Volatility : trade = 48.532875061035156
# Current bid ask spread = 4.5
# ..
# Interval Number :  7
# ..
# SELL SIDE
# [2160.05, 1.0]
# [2160.0, 500.0]
# [2160.0, 200.0]
# [2160.0, 200.0]
# [2160.0, 42.0]
# <---------->
# [2140.05, 157.0]
# [2140.0, 5.0]
# [2140.0, 2.0]
# [2140.0, 1.0]
# [2140.0, 1.0]
# BUY SIDE
# Volatility : buy = 59.107276916503906
# Volatility : sell = 58.156471252441406
# Volatility : trade = 65.4061508178711
# Current bid ask spread = 19.949951171875
# ..
# Interval Number :  8
# ..
# SELL SIDE
# [2177.9, 10.0]
# [2177.9, 1.0]
# [2177.8, 10.0]
# [2177.8, 10.0]
# [2177.7, 130.0]
# <---------->
# [2176.1, 157.0]
# [2175.25, 20.0]
# [2175.0, 157.0]
# [2174.1, 28.0]
# [2174.0, 200.0]
# BUY SIDE
# Volatility : buy = 75.43456268310547
# Volatility : sell = 51.11709976196289
# Volatility : trade = 69.91686248779297
# Current bid ask spread = 1.599853515625
# ..
# Interval Number :  9
# ..
# SELL SIDE
# [2174.95, 9.0]
# [2170.0, 2.0]
# [2169.95, 15.0]
# [2169.9, 1.0]
# [2169.0, 184.0]
# <---------->
# [2168.95, 13.0]
# [2168.0, 25.0]
# [2168.0, 25.0]
# [2167.65, 10.0]
# [2167.5, 1.0]
# BUY SIDE
# Volatility : buy = 87.43794250488281
# Volatility : sell = 47.79862976074219
# Volatility : trade = 71.79692840576172
# Current bid ask spread = 0.050048828125
# ..
# Interval Number :  10
# ..
# SELL SIDE
# [2169.8, 2.0]
# [2169.55, 5.0]
# [2169.45, 5.0]
# [2169.0, 100.0]
# [2169.0, 100.0]
# <---------->
# [2165.15, 37.0]
# [2165.0, 452.0]
# [2165.0, 1.0]
# [2165.0, 1.0]
# [2165.0, 1.0]
# BUY SIDE
# Volatility : buy = 91.06885528564453
# Volatility : sell = 46.61954116821289
# Volatility : trade = 72.19603729248047
# Current bid ask spread = 3.85009765625
# ..
# Interval Number :  11
# ..
# SELL SIDE
# [2184.95, 15.0]
# [2184.95, 15.0]
# [2184.95, 5.0]
# [2184.9, 200.0]
# [2184.9, 74.0]
# <---------->
# [2181.0, 39.0]
# [2180.2, 2.0]
# [2180.0, 10.0]
# [2178.9, 17.0]
# [2178.1, 282.0]
# BUY SIDE
# Volatility : buy = 98.21871185302734
# Volatility : sell = 45.17555618286133
# Volatility : trade = 74.54457092285156
# Current bid ask spread = 3.89990234375
# ..
# Interval Number :  12
# ..
# SELL SIDE
# [2197.9, 10.0]
# [2197.0, 200.0]
# [2197.0, 180.0]
# [2197.0, 5.0]
# [2196.9, 106.0]
# <---------->
# [2190.2, 50.0]
# [2190.0, 100.0]
# [2181.0, 39.0]
# [2181.0, 1.0]
# [2180.2, 2.0]
# BUY SIDE
# Volatility : buy = 98.10033416748047
# Volatility : sell = 52.53768539428711
# Volatility : trade = 78.55924224853516
# Current bid ask spread = 6.699951171875
# ..
# Day :  47
# ---------
# Interval Number :  1
# ..
# SELL SIDE
# [2190.0, 10.0]
# [2190.0, 1.0]
# [2189.8, 28.0]
# [2189.8, 19.0]
# [2189.0, 95.0]
# <---------->
# [2187.0, 3.0]
# [2187.0, 1.0]
# [2186.2, 5.0]
# [2186.15, 14.0]
# [2186.05, 5.0]
# BUY SIDE
# Volatility : buy = 85.94137573242188
# Volatility : sell = 73.16119384765625
# Volatility : trade = 26.72047996520996
# Current bid ask spread = 2.0
# ..
# Interval Number :  2
# ..
# SELL SIDE
# [2230.05, 3.0]
# [2230.05, 3.0]
# [2230.05, 2.0]
# [2230.0, 300.0]
# [2230.0, 35.0]
# <---------->
# [2225.0, 5.0]
# [2225.0, 1.0]
# [2225.0, 1.0]
# [2222.0, 16.0]
# [2222.0, 5.0]
# BUY SIDE
# Volatility : buy = 83.95240783691406
# Volatility : sell = 67.5246810913086
# Volatility : trade = 30.394420623779297
# Current bid ask spread = 5.0
# ..
# Interval Number :  3
# ..
# SELL SIDE
# [2244.0, 3.0]
# [2243.95, 16.0]
# [2243.0, 65.0]
# [2243.0, 35.0]
# [2243.0, 1.0]
# <---------->
# [2240.0, 999.0]
# [2240.0, 148.0]
# [2240.0, 142.0]
# [2240.0, 128.0]
# [2240.0, 80.0]
# BUY SIDE
# Volatility : buy = 85.75589752197266
# Volatility : sell = 58.587833404541016
# Volatility : trade = 30.45244598388672
# Current bid ask spread = 3.0
# ..
# Interval Number :  4
# ..
# SELL SIDE
# [2247.8, 77.0]
# [2247.8, 77.0]
# [2247.5, 10.0]
# [2247.5, 1.0]
# [2247.0, 212.0]
# <---------->
# [2246.0, 2.0]
# [2246.0, 2.0]
# [2246.0, 2.0]
# [2245.65, 25.0]
# [2245.55, 195.0]
# BUY SIDE
# Volatility : buy = 83.29486083984375
# Volatility : sell = 55.41548156738281
# Volatility : trade = 30.40515899658203
# Current bid ask spread = 1.0
# ..
# Interval Number :  5
# ..
# SELL SIDE
# [2249.85, 10.0]
# [2249.85, 10.0]
# [2249.85, 5.0]
# [2249.85, 5.0]
# [2249.8, 3.0]
# <---------->
# [2246.0, 172.0]
# [2246.0, 164.0]
# [2246.0, 10.0]
# [2246.0, 10.0]
# [2246.0, 10.0]
# BUY SIDE
# Volatility : buy = 84.45890808105469
# Volatility : sell = 54.82683181762695
# Volatility : trade = 30.580764770507812
# Current bid ask spread = 3.800048828125
# ..
# Interval Number :  6
# ..
# SELL SIDE
# [2258.5, 10.0]
# [2258.5, 5.0]
# [2258.25, 5.0]
# [2258.05, 15.0]
# [2258.0, 8.0]
# <---------->
# [2254.0, 185.0]
# [2250.05, 5.0]
# [2250.0, 10.0]
# [2249.5, 200.0]
# [2249.4, 200.0]
# BUY SIDE
# Volatility : buy = 84.6622543334961
# Volatility : sell = 55.16392517089844
# Volatility : trade = 33.819515228271484
# Current bid ask spread = 4.0
# ..
# Interval Number :  7
# ..
# SELL SIDE
# [2260.0, 1.0]
# [2258.0, 15.0]
# [2257.0, 15.0]
# [2257.0, 10.0]
# [2257.0, 4.0]
# <---------->
# [2256.0, 50.0]
# [2256.0, 45.0]
# [2255.0, 5.0]
# [2254.0, 5.0]
# [2254.0, 3.0]
# BUY SIDE
# Volatility : buy = 83.96146392822266
# Volatility : sell = 54.6711311340332
# Volatility : trade = 33.795005798339844
# Current bid ask spread = 1.0
# ..
# Interval Number :  8
# ..
# SELL SIDE
# [2249.5, 5.0]
# [2249.0, 200.0]
# [2249.0, 200.0]
# [2249.0, 200.0]
# [2249.0, 21.0]
# <---------->
# [2245.3, 10.0]
# [2245.3, 5.0]
# [2245.25, 5.0]
# [2245.2, 10.0]
# [2245.2, 10.0]
# BUY SIDE
# Volatility : buy = 81.55583190917969
# Volatility : sell = 53.15602493286133
# Volatility : trade = 33.282047271728516
# Current bid ask spread = 3.699951171875
# ..
# Interval Number :  9
# ..
# SELL SIDE
# [2257.65, 10.0]
# [2257.65, 10.0]
# [2257.55, 200.0]
# [2257.55, 195.0]
# [2257.55, 143.0]
# <---------->
# [2256.0, 50.0]
# [2252.0, 10.0]
# [2252.0, 10.0]
# [2252.0, 1.0]
# [2251.8, 10.0]
# BUY SIDE
# Volatility : buy = 80.06354522705078
# Volatility : sell = 53.237735748291016
# Volatility : trade = 33.21160125732422
# Current bid ask spread = 1.550048828125
# ..
# Interval Number :  10
# ..
# SELL SIDE
# [2258.85, 200.0]
# [2258.85, 10.0]
# [2258.85, 10.0]
# [2258.65, 9.0]
# [2257.0, 1.0]
# <---------->
# [2255.5, 88.0]
# [2255.5, 1.0]
# [2255.5, 1.0]
# [2255.2, 2.0]
# [2255.0, 1000.0]
# BUY SIDE
# Volatility : buy = 78.9624252319336
# Volatility : sell = 52.20122528076172
# Volatility : trade = 33.36001968383789
# Current bid ask spread = 1.5
# ..
# Interval Number :  11
# ..
# SELL SIDE
# [2260.0, 600.0]
# [2260.0, 600.0]
# [2260.0, 400.0]
# [2260.0, 400.0]
# [2260.0, 62.0]
# <---------->
# [2250.5, 10.0]
# [2250.5, 5.0]
# [2250.5, 5.0]
# [2250.5, 3.0]
# [2250.35, 10.0]
# BUY SIDE
# Volatility : buy = 78.58069610595703
# Volatility : sell = 52.31220245361328
# Volatility : trade = 32.523712158203125
# Current bid ask spread = 9.5
# ..
# Interval Number :  12
# ..
# SELL SIDE
# [2259.95, 10.0]
# [2255.0, 161.0]
# [2253.0, 25.0]
# [2251.75, 10.0]
# [2251.75, 5.0]
# <---------->
# [2250.25, 200.0]
# [2250.1, 57.0]
# [2250.1, 50.0]
# [2250.1, 10.0]
# [2250.1, 10.0]
# BUY SIDE
# Volatility : buy = 78.5064697265625
# Volatility : sell = 52.09688186645508
# Volatility : trade = 32.36408615112305
# Current bid ask spread = 1.5
# ..
# Day :  48
# ---------
# Interval Number :  1
# ..
# SELL SIDE
# [2234.0, 18.0]
# [2234.0, 18.0]
# [2234.0, 1.0]
# [2233.9, 200.0]
# [2233.9, 9.0]
# <---------->
# [2230.1, 31.0]
# [2230.1, 16.0]
# [2230.1, 1.0]
# [2230.1, 1.0]
# [2230.0, 1000.0]
# BUY SIDE
# Volatility : buy = 74.23638916015625
# Volatility : sell = 93.19049072265625
# Volatility : trade = 37.310943603515625
# Current bid ask spread = 3.7998046875
# ..
# Interval Number :  2
# ..
# SELL SIDE
# [2246.1, 10.0]
# [2246.0, 200.0]
# [2246.0, 200.0]
# [2245.0, 200.0]
# [2245.0, 59.0]
# <---------->
# [2242.15, 123.0]
# [2242.15, 118.0]
# [2242.1, 35.0]
# [2242.05, 50.0]
# [2242.05, 25.0]
# BUY SIDE
# Volatility : buy = 74.71339416503906
# Volatility : sell = 74.31290435791016
# Volatility : trade = 31.910982131958008
# Current bid ask spread = 2.85009765625
# ..
# Interval Number :  3
# ..
# SELL SIDE
# [2244.0, 2.0]
# [2243.8, 10.0]
# [2243.0, 25.0]
# [2242.95, 10.0]
# [2242.9, 153.0]
# <---------->
# [2240.35, 137.0]
# [2240.35, 1.0]
# [2240.3, 93.0]
# [2240.25, 144.0]
# [2240.25, 124.0]
# BUY SIDE
# Volatility : buy = 72.70103454589844
# Volatility : sell = 69.68450927734375
# Volatility : trade = 29.589441299438477
# Current bid ask spread = 2.5498046875
# ..
# Interval Number :  4
# ..
# SELL SIDE
# [2273.95, 10.0]
# [2272.0, 5.0]
# [2270.6, 2.0]
# [2270.1, 38.0]
# [2270.0, 321.0]
# <---------->
# [2261.1, 5.0]
# [2261.0, 2.0]
# [2250.1, 21.0]
# [2250.1, 5.0]
# [2250.0, 3.0]
# BUY SIDE
# Volatility : buy = 71.78330993652344
# Volatility : sell = 67.08853149414062
# Volatility : trade = 27.592809677124023
# Current bid ask spread = 8.89990234375
# ..
# Interval Number :  5
# ..
# SELL SIDE
# [2280.0, 40.0]
# [2280.0, 30.0]
# [2280.0, 25.0]
# [2280.0, 25.0]
# [2280.0, 21.0]
# <---------->
# [2278.05, 6.0]
# [2278.0, 10.0]
# [2278.0, 5.0]
# [2278.0, 4.0]
# [2277.0, 8.0]
# BUY SIDE
# Volatility : buy = 71.95940399169922
# Volatility : sell = 64.49359130859375
# Volatility : trade = 27.47139549255371
# Current bid ask spread = 1.949951171875
# ..
# Interval Number :  6
# ..
# SELL SIDE
# [2290.0, 30.0]
# [2290.0, 30.0]
# [2290.0, 25.0]
# [2290.0, 25.0]
# [2290.0, 8.0]
# <---------->
# [2288.05, 2.0]
# [2288.0, 500.0]
# [2285.0, 500.0]
# [2281.3, 200.0]
# [2281.3, 200.0]
# BUY SIDE
# Volatility : buy = 71.8023910522461
# Volatility : sell = 69.57581329345703
# Volatility : trade = 28.259389877319336
# Current bid ask spread = 1.949951171875
# ..
# Interval Number :  7
# ..
# SELL SIDE
# [2300.0, 100.0]
# [2300.0, 50.0]
# [2300.0, 50.0]
# [2300.0, 50.0]
# [2300.0, 26.0]
# <---------->
# [2295.1, 5.0]
# [2295.0, 1.0]
# [2290.1, 9.0]
# [2290.0, 50.0]
# [2290.0, 5.0]
# BUY SIDE
# Volatility : buy = 71.12110900878906
# Volatility : sell = 64.71432495117188
# Volatility : trade = 29.338302612304688
# Current bid ask spread = 4.89990234375
# ..
# Interval Number :  8
# ..
# SELL SIDE
# [2294.9, 10.0]
# [2294.8, 10.0]
# [2294.7, 10.0]
# [2294.0, 15.0]
# [2294.0, 1.0]
# <---------->
# [2291.0, 7.0]
# [2291.0, 1.0]
# [2291.0, 1.0]
# [2290.0, 5.0]
# [2290.0, 5.0]
# BUY SIDE
# Volatility : buy = 71.42091369628906
# Volatility : sell = 63.48768615722656
# Volatility : trade = 30.288400650024414
# Current bid ask spread = 3.0
# ..
# Interval Number :  9
# ..
# SELL SIDE
# [2274.0, 1.0]
# [2274.0, 1.0]
# [2273.95, 8.0]
# [2273.9, 10.0]
# [2273.9, 9.0]
# <---------->
# [2270.5, 127.0]
# [2270.2, 106.0]
# [2270.2, 20.0]
# [2270.15, 25.0]
# [2270.15, 10.0]
# BUY SIDE
# Volatility : buy = 69.30821228027344
# Volatility : sell = 62.3195686340332
# Volatility : trade = 30.316469192504883
# Current bid ask spread = 3.39990234375
# ..
# Interval Number :  10
# ..
# SELL SIDE
# [2270.0, 10.0]
# [2270.0, 2.0]
# [2270.0, 1.0]
# [2270.0, 1.0]
# [2269.9, 1.0]
# <---------->
# [2265.2, 35.0]
# [2265.2, 20.0]
# [2265.2, 10.0]
# [2265.2, 1.0]
# [2265.15, 3.0]
# BUY SIDE
# Volatility : buy = 66.99915313720703
# Volatility : sell = 62.25046157836914
# Volatility : trade = 29.67150115966797
# Current bid ask spread = 4.699951171875
# ..
# Interval Number :  11
# ..
# SELL SIDE
# [2274.9, 10.0]
# [2274.9, 5.0]
# [2274.85, 20.0]
# [2274.85, 20.0]
# [2274.0, 563.0]
# <---------->
# [2257.3, 10.0]
# [2257.3, 2.0]
# [2257.3, 1.0]
# [2257.0, 50.0]
# [2257.0, 50.0]
# BUY SIDE
# Volatility : buy = 64.71414947509766
# Volatility : sell = 62.898250579833984
# Volatility : trade = 28.57115364074707
# Current bid ask spread = 16.699951171875
# ..
# Day :  49
# ---------
# Interval Number :  1
# ..
# SELL SIDE
# [2132.9, 10.0]
# [2132.9, 2.0]
# [2132.8, 5.0]
# [2132.0, 5.0]
# [2131.95, 20.0]
# <---------->
# [2130.0, 500.0]
# [2130.0, 499.0]
# [2130.0, 62.0]
# [2125.0, 1000.0]
# [2125.0, 5.0]
# BUY SIDE
# Volatility : buy = 58.78800582885742
# Volatility : sell = 87.74258422851562
# Volatility : trade = 40.423736572265625
# Current bid ask spread = 1.949951171875
# ..
# Interval Number :  2
# ..
# SELL SIDE
# [2139.0, 3.0]
# [2138.9, 163.0]
# [2136.1, 5.0]
# [2136.0, 5.0]
# [2135.0, 131.0]
# <---------->
# [2133.0, 52.0]
# [2133.0, 37.0]
# [2133.0, 9.0]
# [2133.0, 1.0]
# [2132.55, 11.0]
# BUY SIDE
# Volatility : buy = 60.928863525390625
# Volatility : sell = 67.98187255859375
# Volatility : trade = 32.1776008605957
# Current bid ask spread = 2.0
# ..
# Interval Number :  3
# ..
# SELL SIDE
# [2149.9, 5.0]
# [2149.9, 3.0]
# [2149.85, 50.0]
# [2149.85, 27.0]
# [2148.0, 4.0]
# <---------->
# [2146.0, 200.0]
# [2146.0, 10.0]
# [2145.0, 100.0]
# [2145.0, 2.0]
# [2145.0, 1.0]
# BUY SIDE
# Volatility : buy = 61.0389289855957
# Volatility : sell = 62.8063850402832
# Volatility : trade = 29.709514617919922
# Current bid ask spread = 2.0
# ..
# Interval Number :  4
# ..
# SELL SIDE
# [2145.0, 3.0]
# [2145.0, 1.0]
# [2145.0, 1.0]
# [2144.95, 5.0]
# [2144.95, 5.0]
# <---------->
# [2140.0, 2215.0]
# [2140.0, 100.0]
# [2140.0, 100.0]
# [2140.0, 100.0]
# [2140.0, 50.0]
# BUY SIDE
# Volatility : buy = 61.94532012939453
# Volatility : sell = 58.45832443237305
# Volatility : trade = 29.278560638427734
# Current bid ask spread = 4.949951171875
# ..
# Interval Number :  5
# ..
# SELL SIDE
# [2145.0, 3038.0]
# [2145.0, 20.0]
# [2145.0, 7.0]
# [2145.0, 5.0]
# [2145.0, 1.0]
# <---------->
# [2140.0, 996.0]
# [2140.0, 988.0]
# [2140.0, 983.0]
# [2140.0, 1.0]
# [2135.0, 100.0]
# BUY SIDE
# Volatility : buy = 64.31179809570312
# Volatility : sell = 60.47035598754883
# Volatility : trade = 26.074377059936523
# Current bid ask spread = 5.0
# ..
# Interval Number :  6
# ..
# SELL SIDE
# [2159.0, 5.0]
# [2159.0, 3.0]
# [2159.0, 1.0]
# [2159.0, 1.0]
# [2158.95, 35.0]
# <---------->
# [2150.0, 13.0]
# [2140.2, 96.0]
# [2140.2, 89.0]
# [2140.2, 89.0]
# [2140.2, 10.0]
# BUY SIDE
# Volatility : buy = 63.83330154418945
# Volatility : sell = 57.85683822631836
# Volatility : trade = 25.71053123474121
# Current bid ask spread = 8.949951171875
# ..
# Interval Number :  7
# ..
# SELL SIDE
# [2160.0, 137.0]
# [2160.0, 50.0]
# [2160.0, 10.0]
# [2160.0, 2.0]
# [2159.0, 50.0]
# <---------->
# [2152.0, 4.0]
# [2152.0, 5.0]
# [2152.0, 3.0]
# [2152.0, 1.0]
# [2151.1, 68.0]
# BUY SIDE
# Volatility : buy = 63.879974365234375
# Volatility : sell = 56.9456901550293
# Volatility : trade = 27.622716903686523
# Current bid ask spread = 7.0
# ..
# Interval Number :  8
# ..
# SELL SIDE
# [2144.8, 20.0]
# [2144.8, 20.0]
# [2144.75, 200.0]
# [2143.9, 5.0]
# [2143.0, 330.0]
# <---------->
# [2140.0, 89.0]
# [2140.0, 120.0]
# [2140.0, 100.0]
# [2140.0, 50.0]
# [2140.0, 50.0]
# BUY SIDE
# Volatility : buy = 61.80098342895508
# Volatility : sell = 54.98921203613281
# Volatility : trade = 26.85272216796875
# Current bid ask spread = 3.0
# ..
# Interval Number :  9
# ..
# SELL SIDE
# [2140.0, 1.0]
# [2139.95, 10.0]
# [2139.95, 10.0]
# [2139.9, 10.0]
# [2139.9, 5.0]
# <---------->
# [2136.05, 95.0]
# [2136.05, 89.0]
# [2136.05, 75.0]
# [2136.05, 9.0]
# [2136.05, 5.0]
# BUY SIDE
# Volatility : buy = 62.34223937988281
# Volatility : sell = 52.9541015625
# Volatility : trade = 26.016674041748047
# Current bid ask spread = 3.849853515625
# ..
# Interval Number :  10
# ..
# SELL SIDE
# [2137.0, 18.0]
# [2135.0, 25.0]
# [2135.0, 1.0]
# [2135.0, 1.0]
# [2134.95, 1.0]
# <---------->
# [2133.5, 20.0]
# [2132.95, 5.0]
# [2132.05, 37.0]
# [2132.05, 20.0]
# [2132.05, 9.0]
# BUY SIDE
# Volatility : buy = 57.71401596069336
# Volatility : sell = 52.3917236328125
# Volatility : trade = 25.071552276611328
# Current bid ask spread = 1.449951171875
# ..
# Interval Number :  11
# ..
# SELL SIDE
# [2139.0, 2.0]
# [2139.0, 1.0]
# [2138.95, 50.0]
# [2138.75, 2.0]
# [2134.0, 5.0]
# <---------->
# [2131.0, 52.0]
# [2131.0, 52.0]
# [2131.0, 47.0]
# [2131.0, 40.0]
# [2131.0, 40.0]
# BUY SIDE
# Volatility : buy = 57.59075164794922
# Volatility : sell = 50.81591033935547
# Volatility : trade = 24.22245216369629
# Current bid ask spread = 3.0
# ..
# Day :  50
# ---------
# Interval Number :  1
# ..
# SELL SIDE
# [2200.0, 2000.0]
# [2200.0, 100.0]
# [2200.0, 50.0]
# [2200.0, 50.0]
# [2200.0, 25.0]
# <---------->
# [2198.0, 100.0]
# [2198.0, 50.0]
# [2195.0, 1.0]
# [2194.0, 50.0]
# [2192.2, 10.0]
# BUY SIDE
# Volatility : buy = 78.94622802734375
# Volatility : sell = 56.233001708984375
# Volatility : trade = 19.119497299194336
# Current bid ask spread = 2.0
# ..
# Interval Number :  2
# ..
# SELL SIDE
# [2194.75, 97.0]
# [2194.0, 200.0]
# [2194.0, 200.0]
# [2194.0, 20.0]
# [2193.0, 15.0]
# <---------->
# [2190.3, 39.0]
# [2190.3, 35.0]
# [2190.3, 24.0]
# [2190.25, 183.0]
# [2190.25, 183.0]
# BUY SIDE
# Volatility : buy = 76.41110229492188
# Volatility : sell = 55.848663330078125
# Volatility : trade = 16.343103408813477
# Current bid ask spread = 2.699951171875
# ..
# Interval Number :  3
# ..
# SELL SIDE
# [2194.8, 20.0]
# [2194.75, 97.0]
# [2194.0, 200.0]
# [2194.0, 43.0]
# [2190.0, 10.0]
# <---------->
# [2180.05, 100.0]
# [2180.05, 107.0]
# [2180.05, 101.0]
# [2180.05, 10.0]
# [2180.05, 9.0]
# BUY SIDE
# Volatility : buy = 71.2925796508789
# Volatility : sell = 54.35472869873047
# Volatility : trade = 21.110294342041016
# Current bid ask spread = 9.949951171875
# ..
# Interval Number :  4
# ..
# SELL SIDE
# [2182.85, 10.0]
# [2182.0, 10.0]
# [2181.9, 5.0]
# [2181.0, 1.0]
# [2180.0, 80.0]
# <---------->
# [2176.0, 14.0]
# [2174.0, 197.0]
# [2173.3, 10.0]
# [2173.1, 155.0]
# [2173.1, 155.0]
# BUY SIDE
# Volatility : buy = 68.36160278320312
# Volatility : sell = 53.67848205566406
# Volatility : trade = 24.796886444091797
# Current bid ask spread = 4.0
# ..
# Interval Number :  5
# ..
# SELL SIDE
# [2178.2, 5.0]
# [2178.0, 10.0]
# [2178.0, 10.0]
# [2176.0, 51.0]
# [2176.0, 10.0]
# <---------->
# [2173.15, 15.0]
# [2173.1, 155.0]
# [2173.1, 155.0]
# [2173.1, 150.0]
# [2173.1, 150.0]
# BUY SIDE
# Volatility : buy = 65.98799896240234
# Volatility : sell = 53.252235412597656
# Volatility : trade = 24.97197723388672
# Current bid ask spread = 2.85009765625
# ..
# Interval Number :  6
# ..
# SELL SIDE
# [2166.95, 30.0]
# [2166.95, 10.0]
# [2166.95, 10.0]
# [2166.95, 10.0]
# [2166.0, 57.0]
# <---------->
# [2164.2, 123.0]
# [2164.0, 200.0]
# [2164.0, 185.0]
# [2164.0, 108.0]
# [2164.0, 50.0]
# BUY SIDE
# Volatility : buy = 64.35807800292969
# Volatility : sell = 53.369869232177734
# Volatility : trade = 25.228538513183594
# Current bid ask spread = 1.800048828125
# ..
# Interval Number :  7
# ..
# SELL SIDE
# [2164.5, 10.0]
# [2164.45, 9.0]
# [2164.0, 57.0]
# [2164.0, 5.0]
# [2163.95, 3.0]
# <---------->
# [2162.0, 144.0]
# [2162.0, 135.0]
# [2162.0, 100.0]
# [2162.0, 77.0]
# [2162.0, 55.0]
# BUY SIDE
# Volatility : buy = 63.753421783447266
# Volatility : sell = 53.514888763427734
# Volatility : trade = 25.070049285888672
# Current bid ask spread = 1.949951171875
# ..
# Interval Number :  8
# ..
# SELL SIDE
# [2163.0, 5.0]
# [2163.0, 5.0]
# [2163.0, 5.0]
# [2163.0, 5.0]
# [2163.0, 3.0]
# <---------->
# [2156.0, 5.0]
# [2156.0, 1.0]
# [2156.0, 1.0]
# [2156.0, 1.0]
# [2155.75, 3.0]
# BUY SIDE
# Volatility : buy = 63.151878356933594
# Volatility : sell = 54.41998291015625
# Volatility : trade = 24.825796127319336
# Current bid ask spread = 7.0
# ..
# Interval Number :  9
# ..
# SELL SIDE
# [2099.0, 114.0]
# [2099.0, 101.0]
# [2099.0, 2.0]
# [2095.0, 1.0]
# [2090.3, 20.0]
# <---------->
# [2070.05, 189.0]
# [2070.05, 165.0]
# [2070.05, 74.0]
# [2070.05, 10.0]
# [2070.0, 1000.0]
# BUY SIDE
# Volatility : buy = 53.59107208251953
# Volatility : sell = 54.80962371826172
# Volatility : trade = 34.89554977416992
# Current bid ask spread = 20.25
# ..
# Interval Number :  10
# ..
# SELL SIDE
# [2039.0, 5.0]
# [2030.0, 25.0]
# [2030.0, 25.0]
# [2030.0, 5.0]
# [2025.0, 1.0]
# <---------->
# [2020.0, 188.0]
# [2020.0, 181.0]
# [2020.0, 101.0]
# [2020.0, 100.0]
# [2020.0, 100.0]
# BUY SIDE
# Volatility : buy = 46.33673095703125
# Volatility : sell = 57.75050354003906
# Volatility : trade = 56.45294189453125
# Current bid ask spread = 5.0
# ..
# Interval Number :  11
# ..
# SELL SIDE
# [1990.0, 25.0]
# [1990.0, 10.0]
# [1990.0, 1.0]
# [1990.0, 1.0]
# [1989.9, 200.0]
# <---------->
# [1985.0, 195.0]
# [1985.0, 193.0]
# [1985.0, 193.0]
# [1985.0, 189.0]
# [1985.0, 189.0]
# BUY SIDE
# Volatility : buy = 44.614288330078125
# Volatility : sell = 87.560302734375
# Volatility : trade = 76.38663482666016
# Current bid ask spread = 4.9000244140625
# ..
# Interval Number :  12
# ..
# SELL SIDE
# [1985.0, 1.0]
# [1985.0, 1.0]
# [1985.0, 1.0]
# [1984.9, 10.0]
# [1984.85, 175.0]
# <---------->
# [1980.0, 529.0]
# [1980.0, 528.0]
# [1980.0, 528.0]
# [1980.0, 527.0]
# [1980.0, 526.0]
# BUY SIDE
# Volatility : buy = 44.65100860595703
# Volatility : sell = 94.35540771484375
# Volatility : trade = 77.60967254638672
# Current bid ask spread = 4.8499755859375
# ..
# Day :  51
# ---------
# Interval Number :  1
# ..
# SELL SIDE
# [2004.5, 1.0]
# [2004.0, 5.0]
# [2004.0, 3.0]
# [2003.0, 10.0]
# [2002.5, 1.0]
# <---------->
# [2001.0, 82.0]
# [2001.0, 57.0]
# [2001.0, 20.0]
# [2001.0, 5.0]
# [2001.0, 5.0]
# BUY SIDE
# Volatility : buy = 66.2284164428711
# Volatility : sell = 71.02405548095703
# Volatility : trade = 20.974895477294922
# Current bid ask spread = 1.5
# ..
# Interval Number :  2
# ..
# SELL SIDE
# [2001.95, 194.0]
# [2001.95, 194.0]
# [2001.8, 10.0]
# [2001.5, 609.0]
# [2001.0, 497.0]
# <---------->
# [2000.0, 175.0]
# [2000.0, 170.0]
# [2000.0, 107.0]
# [2000.0, 103.0]
# [2000.0, 100.0]
# BUY SIDE
# Volatility : buy = 58.51539611816406
# Volatility : sell = 73.01045989990234
# Volatility : trade = 25.1181583404541
# Current bid ask spread = 1.0
# ..
# Interval Number :  3
# ..
# SELL SIDE
# [2006.0, 50.0]
# [2006.0, 50.0]
# [2006.0, 30.0]
# [2006.0, 25.0]
# [2006.0, 6.0]
# <---------->
# [2004.0, 10.0]
# [2004.0, 5.0]
# [2003.5, 25.0]
# [2003.1, 10.0]
# [2003.1, 10.0]
# BUY SIDE
# Volatility : buy = 55.4018669128418
# Volatility : sell = 71.4207763671875
# Volatility : trade = 26.288761138916016
# Current bid ask spread = 2.0
# ..
# Interval Number :  4
# ..
# SELL SIDE
# [2015.0, 1.0]
# [2015.0, 1.0]
# [2014.9, 1.0]
# [2014.0, 532.0]
# [2010.0, 5.0]
# <---------->
# [2006.5, 155.0]
# [2006.5, 85.0]
# [2006.2, 50.0]
# [2006.15, 191.0]
# [2006.15, 170.0]
# BUY SIDE
# Volatility : buy = 52.33668899536133
# Volatility : sell = 66.34598541259766
# Volatility : trade = 29.211652755737305
# Current bid ask spread = 3.5
# ..
# Interval Number :  5
# ..
# SELL SIDE
# [2019.8, 46.0]
# [2019.8, 32.0]
# [2019.8, 4.0]
# [2019.8, 4.0]
# [2019.75, 183.0]
# <---------->
# [2017.9, 100.0]
# [2017.5, 200.0]
# [2017.0, 300.0]
# [2017.0, 213.0]
# [2017.0, 34.0]
# BUY SIDE
# Volatility : buy = 49.24562454223633
# Volatility : sell = 62.84292984008789
# Volatility : trade = 27.613222122192383
# Current bid ask spread = 1.8499755859375
# ..
# Interval Number :  6
# ..
# SELL SIDE
# [2015.0, 5.0]
# [2015.0, 1.0]
# [2015.0, 1.0]
# [2012.0, 20.0]
# [2012.0, 2.0]
# <---------->
# [2010.15, 184.0]
# [2010.15, 155.0]
# [2010.15, 81.0]
# [2010.15, 34.0]
# [2010.15, 5.0]
# BUY SIDE
# Volatility : buy = 47.256980895996094
# Volatility : sell = 61.0787467956543
# Volatility : trade = 24.673686981201172
# Current bid ask spread = 1.8499755859375
# ..
# Interval Number :  7
# ..
# SELL SIDE
# [2008.75, 100.0]
# [2008.0, 200.0]
# [2008.0, 200.0]
# [2008.0, 25.0]
# [2008.0, 5.0]
# <---------->
# [2005.5, 9.0]
# [2005.0, 1000.0]
# [2005.0, 1000.0]
# [2005.0, 995.0]
# [2005.0, 995.0]
# BUY SIDE
# Volatility : buy = 44.93048095703125
# Volatility : sell = 59.86246871948242
# Volatility : trade = 24.84840965270996
# Current bid ask spread = 2.5
# ..
# Interval Number :  8
# ..
# SELL SIDE
# [2039.9, 200.0]
# [2039.9, 200.0]
# [2039.9, 175.0]
# [2039.9, 1.0]
# [2039.0, 793.0]
# <---------->
# [2035.0, 192.0]
# [2035.0, 1.0]
# [2035.0, 1.0]
# [2033.0, 200.0]
# [2033.0, 195.0]
# BUY SIDE
# Volatility : buy = 43.7823486328125
# Volatility : sell = 64.16606140136719
# Volatility : trade = 23.17424201965332
# Current bid ask spread = 4.0
# ..
# Interval Number :  9
# ..
# SELL SIDE
# [2034.7, 49.0]
# [2034.65, 49.0]
# [2034.6, 100.0]
# [2034.55, 49.0]
# [2033.0, 5.0]
# <---------->
# [2032.05, 160.0]
# [2032.05, 146.0]
# [2032.0, 200.0]
# [2032.0, 200.0]
# [2032.0, 200.0]
# BUY SIDE
# Volatility : buy = 43.22967529296875
# Volatility : sell = 55.51183319091797
# Volatility : trade = 22.78090476989746
# Current bid ask spread = 0.949951171875
# ..
# Interval Number :  10
# ..
# SELL SIDE
# [2037.95, 73.0]
# [2036.5, 200.0]
# [2036.5, 200.0]
# [2036.5, 24.0]
# [2035.25, 1.0]
# <---------->
# [2035.1, 98.0]
# [2035.1, 93.0]
# [2035.1, 57.0]
# [2035.05, 200.0]
# [2035.05, 200.0]
# BUY SIDE
# Volatility : buy = 42.62915802001953
# Volatility : sell = 51.13215255737305
# Volatility : trade = 22.70108985900879
# Current bid ask spread = 0.1500244140625
# ..
# Interval Number :  11
# ..
# SELL SIDE
# [2054.7, 200.0]
# [2054.7, 200.0]
# [2054.5, 200.0]
# [2054.5, 200.0]
# [2054.0, 1732.0]
# <---------->
# [2051.1, 987.0]
# [2041.05, 126.0]
# [2041.05, 96.0]
# [2041.0, 200.0]
# [2041.0, 5.0]
# BUY SIDE
# Volatility : buy = 42.90654373168945
# Volatility : sell = 51.94012451171875
# Volatility : trade = 24.854690551757812
# Current bid ask spread = 2.89990234375
# ..
# Interval Number :  12
# ..
# SELL SIDE
# [2055.0, 1.0]
# [2055.0, 1.0]
# [2055.0, 1.0]
# [2054.95, 200.0]
# [2054.95, 119.0]
# <---------->
# [2052.35, 200.0]
# [2052.2, 190.0]
# [2052.2, 152.0]
# [2052.05, 45.0]
# [2051.1, 1000.0]
# BUY SIDE
# Volatility : buy = 43.572444915771484
# Volatility : sell = 50.36357879638672
# Volatility : trade = 25.01821517944336
# Current bid ask spread = 2.599853515625
# ..
# Day :  52
# ---------
# Interval Number :  1
# ..
# SELL SIDE
# [2169.0, 25.0]
# [2169.0, 5.0]
# [2168.5, 10.0]
# [2167.0, 320.0]
# [2166.0, 5.0]
# <---------->
# [2165.2, 86.0]
# [2165.2, 50.0]
# [2165.2, 50.0]
# [2165.2, 19.0]
# [2165.2, 10.0]
# BUY SIDE
# Volatility : buy = 79.78739166259766
# Volatility : sell = 47.31482696533203
# Volatility : trade = 16.759418487548828
# Current bid ask spread = 0.800048828125
# ..
# Interval Number :  2
# ..
# SELL SIDE
# [2165.0, 1.0]
# [2165.0, 1.0]
# [2164.95, 4.0]
# [2164.0, 10.0]
# [2163.95, 10.0]
# <---------->
# [2161.25, 64.0]
# [2161.25, 15.0]
# [2161.2, 3.0]
# [2161.15, 1.0]
# [2161.1, 200.0]
# BUY SIDE
# Volatility : buy = 70.07830047607422
# Volatility : sell = 46.7021598815918
# Volatility : trade = 15.545504570007324
# Current bid ask spread = 2.699951171875
# ..
# Interval Number :  3
# ..
# SELL SIDE
# [2180.0, 25.0]
# [2180.0, 25.0]
# [2180.0, 25.0]
# [2180.0, 12.0]
# [2180.0, 4.0]
# <---------->
# [2178.05, 89.0]
# [2178.05, 66.0]
# [2178.0, 198.0]
# [2178.0, 198.0]
# [2178.0, 2.0]
# BUY SIDE
# Volatility : buy = 63.12333297729492
# Volatility : sell = 46.52338790893555
# Volatility : trade = 16.419517517089844
# Current bid ask spread = 1.949951171875
# ..
# Interval Number :  4
# ..
# SELL SIDE
# [2220.0, 1.0]
# [2219.95, 200.0]
# [2219.95, 200.0]
# [2219.95, 144.0]
# [2219.95, 69.0]
# <---------->
# [2218.0, 54.0]
# [2218.0, 4.0]
# [2217.5, 35.0]
# [2216.25, 200.0]
# [2216.25, 200.0]
# BUY SIDE
# Volatility : buy = 65.86784362792969
# Volatility : sell = 36.64555358886719
# Volatility : trade = 27.511259078979492
# Current bid ask spread = 1.949951171875
# ..
# Interval Number :  5
# ..
# SELL SIDE
# [2218.0, 5.0]
# [2217.95, 35.0]
# [2217.0, 100.0]
# [2217.0, 82.0]
# [2216.0, 85.0]
# <---------->
# [2215.0, 10.0]
# [2215.0, 10.0]
# [2215.0, 10.0]
# [2215.0, 10.0]
# [2215.0, 10.0]
# BUY SIDE
# Volatility : buy = 65.62399291992188
# Volatility : sell = 36.83637237548828
# Volatility : trade = 29.195287704467773
# Current bid ask spread = 1.0
# ..
# Interval Number :  6
# ..
# SELL SIDE
# [2212.9, 200.0]
# [2212.9, 5.0]
# [2212.9, 2.0]
# [2212.75, 8.0]
# [2212.7, 48.0]
# <---------->
# [2212.1, 50.0]
# [2212.1, 50.0]
# [2212.1, 32.0]
# [2212.1, 25.0]
# [2212.1, 25.0]
# BUY SIDE
# Volatility : buy = 65.85276794433594
# Volatility : sell = 36.61842346191406
# Volatility : trade = 30.412967681884766
# Current bid ask spread = 0.599853515625
# ..
# Interval Number :  7
# ..
# SELL SIDE
# [2215.0, 30.0]
# [2215.0, 25.0]
# [2215.0, 25.0]
# [2215.0, 25.0]
# [2215.0, 10.0]
# <---------->
# [2214.05, 44.0]
# [2214.0, 78.0]
# [2214.0, 20.0]
# [2213.15, 32.0]
# [2213.05, 62.0]
# BUY SIDE
# Volatility : buy = 65.87769317626953
# Volatility : sell = 35.1940803527832
# Volatility : trade = 30.78334617614746
# Current bid ask spread = 0.949951171875
# ..
# Interval Number :  8
# ..
# SELL SIDE
# [2223.65, 50.0]
# [2223.65, 50.0]
# [2223.65, 50.0]
# [2223.45, 154.0]
# [2223.45, 17.0]
# <---------->
# [2213.0, 1.0]
# [2213.0, 1.0]
# [2212.25, 10.0]
# [2212.1, 200.0]
# [2212.1, 200.0]
# BUY SIDE
# Volatility : buy = 65.31720733642578
# Volatility : sell = 35.70061492919922
# Volatility : trade = 31.626384735107422
# Current bid ask spread = 10.449951171875
# ..
# Interval Number :  9
# ..
# SELL SIDE
# [2214.0, 200.0]
# [2214.0, 66.0]
# [2212.0, 10.0]
# [2210.0, 100.0]
# [2210.0, 100.0]
# <---------->
# [2205.0, 25.0]
# [2205.0, 25.0]
# [2205.0, 25.0]
# [2205.0, 24.0]
# [2205.0, 24.0]
# BUY SIDE
# Volatility : buy = 63.555755615234375
# Volatility : sell = 34.983577728271484
# Volatility : trade = 31.391929626464844
# Current bid ask spread = 5.0
# ..
# Interval Number :  10
# ..
# SELL SIDE
# [2175.0, 5.0]
# [2174.95, 30.0]
# [2170.0, 500.0]
# [2168.0, 40.0]
# [2168.0, 10.0]
# <---------->
# [2162.0, 72.0]
# [2162.0, 69.0]
# [2162.0, 50.0]
# [2162.0, 50.0]
# [2162.0, 40.0]
# BUY SIDE
# Volatility : buy = 59.730899810791016
# Volatility : sell = 35.67167663574219
# Volatility : trade = 30.013887405395508
# Current bid ask spread = 6.0
# ..
# Interval Number :  11
# ..
# SELL SIDE
# [2158.95, 10.0]
# [2158.9, 148.0]
# [2158.85, 200.0]
# [2158.8, 200.0]
# [2158.0, 200.0]
# <---------->
# [2156.0, 175.0]
# [2156.0, 175.0]
# [2156.0, 174.0]
# [2156.0, 172.0]
# [2156.0, 171.0]
# BUY SIDE
# Volatility : buy = 56.44286346435547
# Volatility : sell = 39.2162971496582
# Volatility : trade = 30.43151092529297
# Current bid ask spread = 2.0
# ..
# Interval Number :  12
# ..
# SELL SIDE
# [2162.0, 4.0]
# [2160.05, 15.0]
# [2160.0, 372.0]
# [2160.0, 90.0]
# [2160.0, 32.0]
# <---------->
# [2156.0, 170.0]
# [2156.0, 169.0]
# [2156.0, 165.0]
# [2156.0, 165.0]
# [2156.0, 164.0]
# BUY SIDE
# Volatility : buy = 56.7670783996582
# Volatility : sell = 39.5169792175293
# Volatility : trade = 30.418962478637695
# Current bid ask spread = 4.0
# ..
# Day :  53
# ---------
# Interval Number :  1
# ..
# SELL SIDE
# [2138.25, 5.0]
# [2138.0, 20.0]
# [2137.9, 10.0]
# [2137.9, 2.0]
# [2137.45, 126.0]
# <---------->
# [2136.0, 44.0]
# [2136.0, 4.0]
# [2136.0, 1.0]
# [2136.0, 1.0]
# [2136.0, 1.0]
# BUY SIDE
# Volatility : buy = 64.02752685546875
# Volatility : sell = 56.044071197509766
# Volatility : trade = 16.864002227783203
# Current bid ask spread = 1.449951171875
# ..
# Interval Number :  2
# ..
# SELL SIDE
# [2125.4, 200.0]
# [2125.4, 5.0]
# [2125.4, 2.0]
# [2125.3, 20.0]
# [2125.25, 1.0]
# <---------->
# [2124.05, 16.0]
# [2124.0, 200.0]
# [2124.0, 200.0]
# [2124.0, 1.0]
# [2124.0, 1.0]
# BUY SIDE
# Volatility : buy = 52.53533935546875
# Volatility : sell = 53.6741943359375
# Volatility : trade = 18.21946144104004
# Current bid ask spread = 1.199951171875
# ..
# Interval Number :  3
# ..
# SELL SIDE
# [2125.95, 200.0]
# [2125.9, 7.0]
# [2125.9, 1.0]
# [2125.05, 1.0]
# [2125.0, 132.0]
# <---------->
# [2124.0, 41.0]
# [2124.0, 27.0]
# [2124.0, 1.0]
# [2124.0, 1.0]
# [2124.0, 1.0]
# BUY SIDE
# Volatility : buy = 50.55615997314453
# Volatility : sell = 52.10323715209961
# Volatility : trade = 17.45933723449707
# Current bid ask spread = 1.0
# ..
# Interval Number :  4
# ..
# SELL SIDE
# [2131.75, 5.0]
# [2131.75, 5.0]
# [2131.5, 15.0]
# [2131.0, 500.0]
# [2131.0, 64.0]
# <---------->
# [2130.1, 10.0]
# [2130.0, 100.0]
# [2130.0, 25.0]
# [2130.0, 1.0]
# [2130.0, 1.0]
# BUY SIDE
# Volatility : buy = 48.32432174682617
# Volatility : sell = 52.200340270996094
# Volatility : trade = 16.11669921875
# Current bid ask spread = 0.89990234375
# ..
# Interval Number :  5
# ..
# SELL SIDE
# [2123.5, 8.0]
# [2123.5, 1.0]
# [2123.5, 1.0]
# [2123.4, 9.0]
# [2123.35, 10.0]
# <---------->
# [2123.0, 60.0]
# [2123.0, 66.0]
# [2123.0, 61.0]
# [2123.0, 56.0]
# [2123.0, 50.0]
# BUY SIDE
# Volatility : buy = 47.27650451660156
# Volatility : sell = 50.126792907714844
# Volatility : trade = 15.330769538879395
# Current bid ask spread = 0.35009765625
# ..
# Interval Number :  6
# ...
# ..
# Interval Number :  5
# ..
# SELL SIDE
# [2275.0, 1.0]
# [2275.0, 1.0]
# [2275.0, 1.0]
# [2274.9, 26.0]
# [2274.8, 136.0]
# <---------->
# [2273.0, 15.0]
# [2272.35, 5.0]
# [2272.1, 25.0]
# [2272.05, 142.0]
# [2272.0, 100.0]
# BUY SIDE
# Volatility : buy = 75.18179321289062
# Volatility : sell = 43.28741455078125
# Volatility : trade = 16.91344451904297
# Current bid ask spread = 1.800048828125
# ..
# Interval Number :  6
# ..
# SELL SIDE
# [2273.0, 200.0]
# [2273.0, 150.0]
# [2273.0, 93.0]
# [2273.0, 88.0]
# [2272.95, 93.0]
# <---------->
# [2271.1, 356.0]
# [2271.1, 317.0]
# [2271.1, 5.0]
# [2271.1, 5.0]
# [2271.05, 200.0]
# BUY SIDE
# Volatility : buy = 73.31492614746094
# Volatility : sell = 42.23655700683594
# Volatility : trade = 17.21846580505371
# Current bid ask spread = 1.849853515625
# ..
# Interval Number :  7
# ..
# SELL SIDE
# [2272.85, 10.0]
# [2272.8, 10.0]
# [2272.3, 1.0]
# [2272.0, 190.0]
# [2272.0, 135.0]
# <---------->
# [2271.0, 5.0]
# [2270.65, 108.0]
# [2270.65, 106.0]
# [2270.6, 5.0]
# [2270.6, 5.0]
# BUY SIDE
# Volatility : buy = 69.5268783569336
# Volatility : sell = 40.52982711791992
# Volatility : trade = 17.348474502563477
# Current bid ask spread = 1.0
# ..
# Interval Number :  8
# ..
# SELL SIDE
# [2287.0, 1.0]
# [2286.9, 100.0]
# [2286.9, 100.0]
# [2286.75, 36.0]
# [2286.5, 199.0]
# <---------->
# [2283.0, 89.0]
# [2283.0, 10.0]
# [2283.0, 7.0]
# [2282.2, 10.0]
# [2282.1, 10.0]
# BUY SIDE
# Volatility : buy = 69.85364532470703
# Volatility : sell = 39.455039978027344
# Volatility : trade = 17.444042205810547
# Current bid ask spread = 3.5
# ..
# Interval Number :  9
# ..
# SELL SIDE
# [2287.0, 5.0]
# [2287.0, 1.0]
# [2286.95, 1.0]
# [2286.8, 10.0]
# [2285.0, 99.0]
# <---------->
# [2281.05, 10.0]
# [2281.0, 126.0]
# [2280.8, 2.0]
# [2280.75, 5.0]
# [2280.6, 200.0]
# BUY SIDE
# Volatility : buy = 69.2998046875
# Volatility : sell = 40.20537567138672
# Volatility : trade = 16.85177993774414
# Current bid ask spread = 3.949951171875
# ..
# Interval Number :  10
# ..
# SELL SIDE
# [2284.9, 10.0]
# [2284.9, 10.0]
# [2284.8, 10.0]
# [2284.5, 20.0]
# [2284.5, 7.0]
# <---------->
# [2283.0, 140.0]
# [2283.0, 140.0]
# [2283.0, 112.0]
# [2282.1, 100.0]
# [2282.1, 100.0]
# BUY SIDE
# Volatility : buy = 68.122802734375
# Volatility : sell = 38.71095275878906
# Volatility : trade = 16.86190414428711
# Current bid ask spread = 1.5
# ..
# Interval Number :  11
# ..
# SELL SIDE
# [2334.0, 1.0]
# [2333.95, 16.0]
# [2333.95, 14.0]
# [2333.9, 200.0]
# [2333.9, 200.0]
# <---------->
# [2330.0, 197.0]
# [2330.0, 100.0]
# [2330.0, 5.0]
# [2330.0, 5.0]
# [2330.0, 3.0]
# BUY SIDE
# Volatility : buy = 68.36044311523438
# Volatility : sell = 32.68452072143555
# Volatility : trade = 26.471446990966797
# Current bid ask spread = 3.89990234375
# ..
# Interval Number :  12
# ..
# SELL SIDE
# [2330.0, 10.0]
# [2330.0, 7.0]
# [2330.0, 1.0]
# [2329.95, 100.0]
# [2329.95, 18.0]
# <---------->
# [2327.0, 90.0]
# [2325.0, 21.0]
# [2325.0, 11.0]
# [2325.0, 10.0]
# [2325.0, 10.0]
# BUY SIDE
# Volatility : buy = 68.3939208984375
# Volatility : sell = 32.61963653564453
# Volatility : trade = 26.722822189331055
# Current bid ask spread = 2.949951171875
# ..
# Day :  61
# ---------
# Interval Number :  1
# ..
# SELL SIDE
# [2330.0, 987.0]
# [2330.0, 200.0]
# [2330.0, 200.0]
# [2330.0, 170.0]
# [2330.0, 10.0]
# <---------->
# [2327.5, 990.0]
# [2327.25, 401.0]
# [2327.25, 10.0]
# [2326.5, 10.0]
# [2326.1, 35.0]
# BUY SIDE
# Volatility : buy = 58.14884567260742
# Volatility : sell = 48.81563949584961
# Volatility : trade = 33.612998962402344
# Current bid ask spread = 2.5
# ..
# Interval Number :  2
# ..
# SELL SIDE
# [2368.85, 4.0]
# [2368.4, 2.0]
# [2368.0, 142.0]
# [2367.95, 4.0]
# [2367.8, 143.0]
# <---------->
# [2366.05, 20.0]
# [2366.05, 20.0]
# [2366.05, 2.0]
# [2366.0, 95.0]
# [2366.0, 1.0]
# BUY SIDE
# Volatility : buy = 56.20759201049805
# Volatility : sell = 33.321495056152344
# Volatility : trade = 36.057003021240234
# Current bid ask spread = 1.75
# ..
# Interval Number :  3
# ..
# SELL SIDE
# [2362.8, 124.0]
# [2362.75, 10.0]
# [2362.7, 2.0]
# [2362.5, 4.0]
# [2362.0, 2.0]
# <---------->
# [2360.5, 145.0]
# [2360.5, 135.0]
# [2360.5, 130.0]
# [2360.5, 50.0]
# [2360.5, 5.0]
# BUY SIDE
# Volatility : buy = 54.14665603637695
# Volatility : sell = 31.82878303527832
# Volatility : trade = 35.08929443359375
# Current bid ask spread = 1.5
# ..
# Interval Number :  4
# ..
# SELL SIDE
# [2365.0, 100.0]
# [2365.0, 5.0]
# [2365.0, 2.0]
# [2365.0, 1.0]
# [2364.0, 27.0]
# <---------->
# [2362.0, 14.0]
# [2362.0, 91.0]
# [2362.0, 20.0]
# [2362.0, 18.0]
# [2362.0, 18.0]
# BUY SIDE
# Volatility : buy = 52.33332824707031
# Volatility : sell = 30.72046661376953
# Volatility : trade = 32.90243148803711
# Current bid ask spread = 2.0
# ..
# Interval Number :  5
# ..
# SELL SIDE
# [2365.0, 10.0]
# [2363.0, 10.0]
# [2360.0, 10.0]
# [2360.0, 4.0]
# [2360.0, 1.0]
# <---------->
# [2358.05, 30.0]
# [2358.05, 28.0]
# [2358.05, 3.0]
# [2358.0, 98.0]
# [2358.0, 76.0]
# BUY SIDE
# Volatility : buy = 49.90409851074219
# Volatility : sell = 32.00199890136719
# Volatility : trade = 30.46413803100586
# Current bid ask spread = 1.949951171875
# ..
# Interval Number :  6
# ..
# SELL SIDE
# [2357.9, 200.0]
# [2357.9, 160.0]
# [2357.85, 9.0]
# [2357.8, 200.0]
# [2357.8, 150.0]
# <---------->
# [2356.0, 175.0]
# [2356.0, 174.0]
# [2356.0, 160.0]
# [2356.0, 131.0]
# [2356.0, 98.0]
# BUY SIDE
# Volatility : buy = 48.4458122253418
# Volatility : sell = 31.57042121887207
# Volatility : trade = 29.51279640197754
# Current bid ask spread = 1.800048828125
# ..
# Interval Number :  7
# ..
# SELL SIDE
# [2362.65, 175.0]
# [2362.65, 175.0]
# [2362.3, 1.0]
# [2362.05, 8.0]
# [2362.0, 302.0]
# <---------->
# [2361.0, 90.0]
# [2360.65, 2.0]
# [2360.65, 2.0]
# [2360.6, 140.0]
# [2360.5, 100.0]
# BUY SIDE
# Volatility : buy = 47.76288986206055
# Volatility : sell = 32.571075439453125
# Volatility : trade = 28.99860382080078
# Current bid ask spread = 1.0
# ..
# Interval Number :  8
# ..
# SELL SIDE
# [2379.85, 100.0]
# [2379.8, 5.0]
# [2379.8, 5.0]
# [2379.75, 10.0]
# [2379.4, 5.0]
# <---------->
# [2372.05, 20.0]
# [2371.75, 2.0]
# [2371.7, 20.0]
# [2371.65, 174.0]
# [2371.6, 195.0]
# BUY SIDE
# Volatility : buy = 47.27022171020508
# Volatility : sell = 36.06101608276367
# Volatility : trade = 28.496021270751953
# Current bid ask spread = 7.349853515625
# ..
# Interval Number :  9
# ..
# SELL SIDE
# [2407.0, 200.0]
# [2407.0, 200.0]
# [2407.0, 200.0]
# [2407.0, 180.0]
# [2407.0, 14.0]
# <---------->
# [2405.0, 415.0]
# [2405.0, 370.0]
# [2405.0, 5.0]
# [2404.9, 1.0]
# [2404.9, 1.0]
# BUY SIDE
# Volatility : buy = 48.99153137207031
# Volatility : sell = 40.176544189453125
# Volatility : trade = 31.507003784179688
# Current bid ask spread = 2.0
# ..
# Interval Number :  10
# ..
# SELL SIDE
# [2412.5, 200.0]
# [2412.0, 1.0]
# [2412.0, 1.0]
# [2411.9, 10.0]
# [2411.1, 10.0]
# <---------->
# [2410.1, 99.0]
# [2410.1, 99.0]
# [2410.1, 90.0]
# [2410.1, 62.0]
# [2410.1, 2.0]
# BUY SIDE
# Volatility : buy = 55.67584228515625
# Volatility : sell = 40.316287994384766
# Volatility : trade = 35.613746643066406
# Current bid ask spread = 1.0
# ..
# Interval Number :  11
# ..
# SELL SIDE
# [2419.95, 200.0]
# [2419.95, 200.0]
# [2419.95, 200.0]
# [2419.95, 200.0]
# [2419.95, 122.0]
# <---------->
# [2416.0, 100.0]
# [2416.0, 7.0]
# [2415.6, 5.0]
# [2415.05, 53.0]
# [2415.0, 54.0]
# BUY SIDE
# Volatility : buy = 57.050270080566406
# Volatility : sell = 37.64753723144531
# Volatility : trade = 35.62221145629883
# Current bid ask spread = 3.949951171875
# ..
# Interval Number :  12
# ..
# SELL SIDE
# [2425.0, 1.0]
# [2425.0, 1.0]
# [2425.0, 1.0]
# [2424.95, 400.0]
# [2424.95, 115.0]
# <---------->
# [2422.0, 10.0]
# [2422.0, 9.0]
# [2421.1, 100.0]
# [2421.1, 86.0]
# [2421.0, 53.0]
# BUY SIDE
# Volatility : buy = 57.45302200317383
# Volatility : sell = 37.43124008178711
# Volatility : trade = 35.93624496459961
# Current bid ask spread = 2.949951171875
# ..
# Day :  62
# ---------
# Interval Number :  1
# ..
# SELL SIDE
# [2470.0, 2.0]
# [2469.9, 6.0]
# [2469.5, 10.0]
# [2469.0, 20.0]
# [2468.8, 10.0]
# <---------->
# [2468.0, 330.0]
# [2468.0, 200.0]
# [2468.0, 200.0]
# [2468.0, 15.0]
# [2468.0, 15.0]
# BUY SIDE
# Volatility : buy = 71.96682739257812
# Volatility : sell = 45.42121887207031
# Volatility : trade = 27.8541259765625
# Current bid ask spread = 0.800048828125
# ..
# Interval Number :  2
# ..
# SELL SIDE
# [2499.0, 1.0]
# [2499.0, 1.0]
# [2499.0, 1.0]
# [2499.0, 1.0]
# [2499.0, 1.0]
# <---------->
# [2495.0, 38.0]
# [2495.0, 15.0]
# [2493.0, 24.0]
# [2493.0, 10.0]
# [2493.0, 5.0]
# BUY SIDE
# Volatility : buy = 71.63887023925781
# Volatility : sell = 53.97568130493164
# Volatility : trade = 20.82992935180664
# Current bid ask spread = 4.0
# ..
# Interval Number :  3
# ..
# SELL SIDE
# [2493.0, 100.0]
# [2493.0, 32.0]
# [2493.0, 30.0]
# [2491.0, 2.0]
# [2489.95, 186.0]
# <---------->
# [2489.9, 2.0]
# [2489.05, 10.0]
# [2489.0, 20.0]
# [2489.0, 20.0]
# [2489.0, 10.0]
# BUY SIDE
# Volatility : buy = 72.1526870727539
# Volatility : sell = 47.993408203125
# Volatility : trade = 26.630098342895508
# Current bid ask spread = 0.050048828125
# ..
# Interval Number :  4
# ..
# SELL SIDE
# [2473.95, 192.0]
# [2473.65, 301.0]
# [2473.0, 500.0]
# [2473.0, 401.0]
# [2473.0, 115.0]
# <---------->
# [2472.6, 50.0]
# [2472.6, 29.0]
# [2472.6, 1.0]
# [2472.5, 116.0]
# [2472.5, 62.0]
# BUY SIDE
# Volatility : buy = 71.18938446044922
# Volatility : sell = 47.47990417480469
# Volatility : trade = 25.537948608398438
# Current bid ask spread = 0.39990234375
# ..
# Interval Number :  5
# ..
# SELL SIDE
# [2479.95, 200.0]
# [2479.95, 200.0]
# [2479.95, 200.0]
# [2479.95, 200.0]
# [2479.95, 49.0]
# <---------->
# [2479.1, 194.0]
# [2479.1, 189.0]
# [2479.1, 184.0]
# [2479.1, 175.0]
# [2479.0, 25.0]
# BUY SIDE
# Volatility : buy = 68.57147979736328
# Volatility : sell = 45.02915573120117
# Volatility : trade = 25.088830947875977
# Current bid ask spread = 0.849853515625
# ..
# Interval Number :  6
# ..
# SELL SIDE
# [2466.0, 1.0]
# [2465.0, 1.0]
# [2464.95, 100.0]
# [2464.85, 15.0]
# [2464.0, 500.0]
# <---------->
# [2462.0, 50.0]
# [2462.0, 50.0]
# [2462.0, 25.0]
# [2462.0, 25.0]
# [2462.0, 25.0]
# BUY SIDE
# Volatility : buy = 71.62696838378906
# Volatility : sell = 45.12269973754883
# Volatility : trade = 24.006000518798828
# Current bid ask spread = 2.0
# ..
# Interval Number :  7
# ..
# SELL SIDE
# [2455.0, 5.0]
# [2455.0, 5.0]
# [2455.0, 1.0]
# [2455.0, 1.0]
# [2453.5, 4.0]
# <---------->
# [2453.0, 54.0]
# [2452.0, 729.0]
# [2452.0, 20.0]
# [2452.0, 1.0]
# [2450.4, 5.0]
# BUY SIDE
# Volatility : buy = 66.84822082519531
# Volatility : sell = 44.82866668701172
# Volatility : trade = 25.824045181274414
# Current bid ask spread = 0.5
# ..
# Interval Number :  8
# ..
# SELL SIDE
# [2441.0, 41.0]
# [2441.0, 1.0]
# [2440.0, 1.0]
# [2440.0, 1.0]
# [2439.0, 781.0]
# <---------->
# [2438.95, 33.0]
# [2438.95, 27.0]
# [2438.5, 1.0]
# [2438.05, 4.0]
# [2438.0, 100.0]
# BUY SIDE
# Volatility : buy = 64.86077880859375
# Volatility : sell = 45.20809555053711
# Volatility : trade = 26.416606903076172
# Current bid ask spread = 0.050048828125
# ..
# Interval Number :  9
# ..
# SELL SIDE
# [2438.65, 5.0]
# [2438.6, 150.0]
# [2438.6, 150.0]
# [2438.5, 125.0]
# [2438.0, 10.0]
# <---------->
# [2437.0, 4.0]
# [2436.2, 2.0]
# [2436.15, 190.0]
# [2436.15, 190.0]
# [2436.15, 2.0]
# BUY SIDE
# Volatility : buy = 61.610443115234375
# Volatility : sell = 45.77448654174805
# Volatility : trade = 27.13487434387207
# Current bid ask spread = 1.0
# ..
# Interval Number :  10
# ..
# SELL SIDE
# [2452.0, 19.0]
# [2451.95, 200.0]
# [2451.9, 500.0]
# [2451.9, 10.0]
# [2451.85, 164.0]
# <---------->
# [2450.25, 27.0]
# [2450.1, 25.0]
# [2450.05, 26.0]
# [2450.05, 25.0]
# [2450.0, 5230.0]
# BUY SIDE
# Volatility : buy = 60.96360778808594
# Volatility : sell = 44.46217346191406
# Volatility : trade = 26.78663444519043
# Current bid ask spread = 1.60009765625
# ..
# Interval Number :  11
# ..
# SELL SIDE
# [2450.5, 5.0]
# [2450.5, 2.0]
# [2450.2, 2701.0]
# [2450.2, 643.0]
# [2450.15, 10.0]
# <---------->
# [2450.1, 302.0]
# [2450.1, 40.0]
# [2450.0, 8870.0]
# [2450.0, 6363.0]
# [2450.0, 6293.0]
# BUY SIDE
# Volatility : buy = 59.71657180786133
# Volatility : sell = 43.71966552734375
# Volatility : trade = 26.448238372802734
# Current bid ask spread = 0.0498046875
# ..
# Interval Number :  12
# ..
# SELL SIDE
# [2450.5, 7.0]
# [2450.5, 5.0]
# [2450.5, 2.0]
# [2450.2, 2701.0]
# [2450.2, 276.0]
# <---------->
# [2450.0, 9438.0]
# [2450.0, 9127.0]
# [2450.0, 5884.0]
# [2450.0, 5848.0]
# [2450.0, 5581.0]
# BUY SIDE
# Volatility : buy = 62.586509704589844
# Volatility : sell = 43.39409637451172
# Volatility : trade = 26.38642120361328
# Current bid ask spread = 0.199951171875
# ..
# Day :  63
# ---------
# Interval Number :  1
# ..
# SELL SIDE
# [2500.0, 1618.0]
# [2500.0, 20.0]
# [2500.0, 10.0]
# [2499.9, 200.0]
# [2499.9, 200.0]
# <---------->
# [2497.05, 125.0]
# [2497.0, 5.0]
# [2497.0, 5.0]
# [2497.0, 1.0]
# [2495.5, 172.0]
# BUY SIDE
# Volatility : buy = 67.14112091064453
# Volatility : sell = 49.47795867919922
# Volatility : trade = 10.390202522277832
# Current bid ask spread = 2.849853515625
# ..
# Interval Number :  2
# ..
# SELL SIDE
# [2493.5, 5.0]
# [2493.4, 10.0]
# [2493.0, 10.0]
# [2491.0, 1.0]
# [2491.0, 1.0]
# <---------->
# [2490.5, 4.0]
# [2490.0, 445.0]
# [2490.0, 424.0]
# [2490.0, 200.0]
# [2490.0, 200.0]
# BUY SIDE
# Volatility : buy = 67.45068359375
# Volatility : sell = 49.69917297363281
# Volatility : trade = 12.092864036560059
# Current bid ask spread = 0.5
# ..
# Interval Number :  3
# ..
# SELL SIDE
# [2495.0, 1.0]
# [2495.0, 1.0]
# [2495.0, 1.0]
# [2494.95, 200.0]
# [2494.95, 146.0]
# <---------->
# [2493.0, 20.0]
# [2492.0, 96.0]
# [2492.0, 93.0]
# [2492.0, 90.0]
# [2492.0, 85.0]
# BUY SIDE
# Volatility : buy = 61.27751159667969
# Volatility : sell = 47.27189636230469
# Volatility : trade = 17.236553192138672
# Current bid ask spread = 1.949951171875
# ..
# Interval Number :  4
# ..
# SELL SIDE
# [2487.0, 1.0]
# [2486.95, 182.0]
# [2485.9, 42.0]
# [2485.9, 42.0]
# [2485.9, 8.0]
# <---------->
# [2485.0, 245.0]
# [2485.0, 71.0]
# [2485.0, 50.0]
# [2485.0, 50.0]
# [2485.0, 50.0]
# BUY SIDE
# Volatility : buy = 61.514286041259766
# Volatility : sell = 46.18121337890625
# Volatility : trade = 17.782543182373047
# Current bid ask spread = 0.89990234375
# ..
# Interval Number :  5
# ..
# SELL SIDE
# [2494.95, 200.0]
# [2494.95, 200.0]
# [2494.95, 200.0]
# [2494.95, 200.0]
# [2494.95, 23.0]
# <---------->
# [2493.0, 25.0]
# [2492.1, 20.0]
# [2492.0, 50.0]
# [2492.0, 10.0]
# [2491.25, 190.0]
# BUY SIDE
# Volatility : buy = 59.6676139831543
# Volatility : sell = 43.62407302856445
# Volatility : trade = 16.826412200927734
# Current bid ask spread = 1.949951171875
# ..
# Interval Number :  6
# ..
# SELL SIDE
# [2497.9, 58.0]
# [2497.9, 10.0]
# [2497.85, 69.0]
# [2497.8, 45.0]
# [2497.75, 2.0]
# <---------->
# [2497.0, 50.0]
# [2497.0, 34.0]
# [2496.0, 21.0]
# [2495.9, 4.0]
# [2495.55, 5.0]
# BUY SIDE
# Volatility : buy = 57.110321044921875
# Volatility : sell = 42.80155944824219
# Volatility : trade = 17.210155487060547
# Current bid ask spread = 0.75
# ..
# Interval Number :  7
# ..
# SELL SIDE
# [2498.0, 1.0]
# [2498.0, 1.0]
# [2498.0, 1.0]
# [2498.0, 1.0]
# [2497.95, 58.0]
# <---------->
# [2496.0, 62.0]
# [2496.0, 25.0]
# [2495.15, 5.0]
# [2495.1, 200.0]
# [2495.1, 200.0]
# BUY SIDE
# Volatility : buy = 56.1952018737793
# Volatility : sell = 41.62599563598633
# Volatility : trade = 17.432979583740234
# Current bid ask spread = 1.949951171875
# ..
# Interval Number :  8
# ..
# SELL SIDE
# [2498.6, 7.0]
# [2498.6, 1.0]
# [2498.55, 34.0]
# [2498.4, 6.0]
# [2498.4, 1.0]
# <---------->
# [2497.5, 612.0]
# [2497.5, 10.0]
# [2497.0, 992.0]
# [2497.0, 2.0]
# [2496.35, 10.0]
# BUY SIDE
# Volatility : buy = 55.538551330566406
# Volatility : sell = 40.28691101074219
# Volatility : trade = 17.34857177734375
# Current bid ask spread = 0.89990234375
# ..
# Interval Number :  9
# ..
# SELL SIDE
# [2497.9, 4.0]
# [2497.9, 3.0]
# [2497.85, 169.0]
# [2497.0, 5.0]
# [2496.0, 50.0]
# <---------->
# [2495.0, 258.0]
# [2495.0, 249.0]
# [2495.0, 242.0]
# [2495.0, 234.0]
# [2495.0, 200.0]
# BUY SIDE
# Volatility : buy = 53.621826171875
# Volatility : sell = 39.14300537109375
# Volatility : trade = 16.89864158630371
# Current bid ask spread = 1.0
# ..
# Interval Number :  10
# ..
# SELL SIDE
# [2499.85, 5.0]
# [2499.8, 200.0]
# [2499.8, 200.0]
# [2499.8, 200.0]
# [2499.8, 180.0]
# <---------->
# [2498.1, 11.0]
# [2498.05, 120.0]
# [2498.0, 113.0]
# [2498.0, 100.0]
# [2498.0, 100.0]
# BUY SIDE
# Volatility : buy = 52.49765396118164
# Volatility : sell = 39.10462951660156
# Volatility : trade = 17.651248931884766
# Current bid ask spread = 1.699951171875
# ..
# Interval Number :  11
# ..
# SELL SIDE
# [2500.0, 10.0]
# [2500.0, 10.0]
# [2500.0, 10.0]
# [2500.0, 4.0]
# [2499.0, 3.0]
# <---------->
# [2498.0, 100.0]
# [2498.0, 99.0]
# [2498.0, 93.0]
# [2498.0, 90.0]
# [2498.0, 75.0]
# BUY SIDE
# Volatility : buy = 51.759586334228516
# Volatility : sell = 38.38658905029297
# Volatility : trade = 17.277992248535156
# Current bid ask spread = 1.0
# ..
# Interval Number :  12
# ..
# SELL SIDE
# [2499.9, 41.0]
# [2499.85, 49.0]
# [2499.8, 202.0]
# [2499.8, 202.0]
# [2499.7, 49.0]
# <---------->
# [2499.0, 119.0]
# [2497.55, 125.0]
# [2497.55, 56.0]
# [2497.5, 10.0]
# [2497.4, 10.0]
# BUY SIDE
# Volatility : buy = 51.88949203491211
# Volatility : sell = 38.01986312866211
# Volatility : trade = 17.311426162719727
# Current bid ask spread = 0.699951171875
# ..

# %%
len(Env.orderbook_daily)
# Out:
# 63

# %%
Env.orderbook_daily[3].snaps[2].describe()
# Out:
# SELL SIDE
# [3208.95, 30.0]
# [3208.95, 2.0]
# [3208.75, 196.0]
# [3208.75, 5.0]
# [3208.0, 26.0]
# <---------->
# [3206.0, 170.0]
# [3206.0, 170.0]
# [3205.05, 53.0]
# [3205.05, 20.0]
# [3205.05, 13.0]
# BUY SIDE
# Volatility : buy = 80.6750259399414
# Volatility : sell = 47.76594924926758
# Volatility : trade = 18.230669021606445
# Current bid ask spread = 2.0

# %%
file_pi = open('/content/drive/MyDrive/limitorderbook/snapshots_total.obj', 'wb') 
pickle.dump(Env, file_pi)

# %%
filehandler = open('/content/drive/MyDrive/limitorderbook/snapshots_total.obj', 'rb') 
Env2 = pickle.load(filehandler)

# %%
Env2.orderbook_daily[3].snaps[2].describe()
# Out:
# SELL SIDE
# [3208.95, 30.0]
# [3208.95, 2.0]
# [3208.75, 196.0]
# [3208.75, 5.0]
# [3208.0, 26.0]
# <---------->
# [3206.0, 170.0]
# [3206.0, 170.0]
# [3205.05, 53.0]
# [3205.05, 20.0]
# [3205.05, 13.0]
# BUY SIDE
# Volatility : buy = 80.6750259399414
# Volatility : sell = 47.76594924926758
# Volatility : trade = 18.230669021606445
# Current bid ask spread = 2.0
